# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## Reading the observational data: r1/2 and Re ======================

data = np.genfromtxt('D:/Research/ultra-faint dwarf galaxies/observational_data/r05_ufd.txt',dtype='str')
r05_ufd = np.array(data[:,2], dtype='float32')
sm_ufd = np.array(data[:,3], dtype='float32')

# %%
r05_ufd_sim1_noRT = np.array([0.19, 0.17, 0.17]) * 1000 #kpc into pc
r05_ufd_sim1_RT = np.array([0.15, 0.15, 0.21]) * 1000 #kpc into pc
sm_ufd_sim1_noRT = np.array([8769.38, 8778.7385, 8778.983]) #M_sun
sm_ufd_sim1_RT = np.array([3247.37, 3247.452, 3247.549]) #M_sun
r05_ufd_sim2_noRT = np.array([0.39, 0.35, 0.45]) * 1000 #kpc into pc
r05_ufd_sim2_RT = np.array([0.03, 0.03, 0.05]) * 1000 #kpc into pc
sm_ufd_sim2_noRT = np.array([3051.31, 3051.3835, 3051.5635]) * 2 #M_sun
sm_ufd_sim2_RT = np.array([1101.5865, 1101.6125000000002, 1101.6795]) * 2 #M_sun

#fig, ax = plt.subplots(figsize=[8, 5])

plt.scatter(np.log10(sm_ufd*1e6), np.log10(r05_ufd), marker='^', s=130, edgecolor='black', 
            color='blue', alpha=0.6, label='MW UFDs')
plt.scatter(np.log10(sm_ufd_sim1_noRT), np.log10(r05_ufd_sim1_noRT), marker='o', s=130, edgecolor='black', 
            color='pink', alpha=0.6, label='UFD1, no RT')
plt.scatter(np.log10(sm_ufd_sim1_RT), np.log10(r05_ufd_sim1_RT), marker='o', s=130, edgecolor='black', 
            color='red', alpha=0.6, label='UFD1, RT')
plt.scatter(np.log10(sm_ufd_sim2_noRT), np.log10(r05_ufd_sim2_noRT), marker='s', s=130, edgecolor='black', 
            color='pink', alpha=0.6, label='UFD2, no RT')
plt.scatter(np.log10(sm_ufd_sim2_RT), np.log10(r05_ufd_sim2_RT), marker='s', s=130, edgecolor='black', 
            color='red', alpha=0.6, label='UFD2, RT')

data = np.genfromtxt('D:/Research/ultra-faint dwarf galaxies/observational_data/r05_dsph.txt',dtype='str')
r05_dsph = np.array(data[:,2], dtype='float32')
sm_dsph = np.array(data[:,3], dtype='float32')
plt.scatter(np.log10(sm_dsph*1e6), np.log10(r05_dsph), marker='^', s=130, edgecolor='black', 
            color='black', alpha=0.6, label='MW dSphs')

plt.legend(loc='lower right')

plt.xlabel('log M$_{*}$ (M$_\odot$)')
plt.ylabel('log r$_{1/2}$ [pc]')

#plt.savefig('logr12logMstar.png')
# Out:
# Text(0, 0.5, 'log r$_{1/2}$ [pc]')

# %%
re_ufd = r05_ufd

re_ufd_sim1_noRT = np.array([0.1425, 0.1275, 0.1275]) * 1000 #kpc into pc
re_ufd_sim1_RT = np.array([0.112, 0.1575, 0.1125]) * 1000 #kpc into pc
sm_ufd_sim1_noRT = np.array([8332.969, 7651.947, 7595.868]) #M_sun
sm_ufd_sim1_RT = np.array([2674.073, 2760.789, 2284.178]) #M_sun
re_ufd_sim2_noRT = np.array([0.2925, 0.2625, 0.3375]) * 1000 #kpc into pc
re_ufd_sim2_RT = np.array([0.0225, 0.0225, 0.0375]) * 1000 #kpc into pc
sm_ufd_sim2_noRT = np.array([2377.715, 2373.857, 2406.623]) * 2 #M_sun
sm_ufd_sim2_RT = np.array([1045.09, 1454.948, 979.175]) * 2 #M_sun

#fig, ax = plt.subplots(figsize=[8, 5])

plt.scatter(np.log10(sm_ufd*1e6), np.log10(re_ufd), marker='^', s=130, edgecolor='black', 
            color='blue', alpha=0.6, label='MW UFDs')
plt.scatter(np.log10(sm_ufd_sim1_noRT), np.log10(re_ufd_sim1_noRT), marker='o', s=130, edgecolor='black', 
            color='pink', alpha=0.6, label='UFD1, no RT')
plt.scatter(np.log10(sm_ufd_sim1_RT), np.log10(re_ufd_sim1_RT), marker='o', s=130, edgecolor='black', 
            color='red', alpha=0.6, label='UFD1, RT')
plt.scatter(np.log10(sm_ufd_sim2_noRT), np.log10(re_ufd_sim2_noRT), marker='s', s=130, edgecolor='black', 
            color='pink', alpha=0.6, label='UFD2, no RT')
plt.scatter(np.log10(sm_ufd_sim2_RT), np.log10(re_ufd_sim2_RT), marker='s', s=130, edgecolor='black', 
            color='red', alpha=0.6, label='UFD2, RT')

data = np.genfromtxt('D:/Research/ultra-faint dwarf galaxies/observational_data/r05_dsph.txt',dtype='str')
re_dsph = np.array(data[:,2], dtype='float32')
sm_dsph = np.array(data[:,3], dtype='float32')
plt.scatter(np.log10(sm_dsph*1e6), np.log10(re_dsph), marker='^', s=130, edgecolor='black', 
            color='black', alpha=0.6, label='MW dSphs')

plt.legend(loc='lower right')

plt.xlabel('log M$_{*}$ (M$_\odot$)')
plt.ylabel('log R$_{e}$ [pc]')

#plt.savefig('logRe.png')
# Out:
# Text(0, 0.5, 'log R$_{e}$ [pc]')

# %% [markdown]
# ### Reading the observational data: dispersion for Re ======================
#
# disp_1_noRT_130 = [4.31445362, 3.59451416, 5.24697993]
# #disp_1_noRT_245 = [2.63452563, 2.99682817, 3.48360108]
# #disp_1_noRT_373 = [3.09288327, 2.64437929, 4.17680631]
# #disp_1_RT_130 = [2.37652727, 4.44812776, 3.27161215]
# #disp_1_RT_245 = [2.6098263,  3.14704518, 2.60759418]
# #disp_1_RT_373 = [2.44408368, 1.68432858, 3.65726145]
# mass_1_noRT_130 = [8332.969, 8332.969, 8332.969]
# mass_1_noRT_245 = [7595.868, 7595.868, 7595.868]
# mass_1_noRT_373 = [7651.947, 7651.947, 7651.947]
# mass_1_RT_130 = [2674.073, 2674.073, 2674.073]
# mass_1_RT_245 = [2284.178, 2284.178, 2284.178]
# mass_1_RT_373 = [2760.789, 2760.789, 2760.789]
#
# #disp_2_noRT_024 = [2.68023204, 1.65084161, 1.99861127]
# mass_2_noRT_024 = [2377.715, 2377.715, 2377.715]
# #disp_2_noRT_130 = [2.50288539, 2.35642292, 1.65302327]
# mass_2_noRT_130 = [2373.857, 2373.857, 2373.857]
# #disp_2_noRT_373 = [1.06515131, 1.4243969,  1.8163666]
# mass_2_noRT_373 = [2406.623, 2406.623, 2406.623]
# #disp_2_RT_024 = [1.07893852, 1.64087336, 1.5180028]
# mass_2_RT_024 = [1045.09, 1045.09, 1045.09]
# #disp_2_RT_130 = [1.32618683, 0.40673541, 1.64995959]
# mass_2_RT_130 = [1454.948, 1454.948, 1454.948]
# #disp_2_RT_373 = [0.34942696, 1.66234639, 0.70803739]
# mass_2_RT_373 = [979.175, 979.175, 979.175]
#
# #fig, ax = plt.subplots(figsize=[8, 5])
#
# plt.scatter(np.log10(mass_1_noRT_130), disp_1_noRT_130, marker='P', s=150, edgecolor='black', alpha=0.6, color='yellow', \
#            label='UFD1, no RT, z=0.130')
# plt.scatter(np.log10(mass_1_noRT_245), disp_1_noRT_245, marker='P', s=150, edgecolor='black', alpha=0.6, color='orange', \
#            label='UFD1, no RT, z=0.245')
# plt.scatter(np.log10(mass_1_noRT_373), disp_1_noRT_373, marker='P', s=150, edgecolor='black', alpha=0.6, color='red', \
#            label='UFD1, no RT, z=0.373')
#
# plt.scatter(np.log10(mass_1_RT_130), disp_1_RT_130, marker='o', s=150, edgecolor='black', alpha=0.6, color='yellow', \
#            label='UFD1, RT, z=0.130')
# plt.scatter(np.log10(mass_1_RT_245), disp_1_RT_245, marker='o', s=150, edgecolor='black', alpha=0.6, color='orange', \
#            label='UFD1, RT, z=0.245')
# plt.scatter(np.log10(mass_1_RT_373), disp_1_RT_373, marker='o', s=150, edgecolor='black', alpha=0.6, color='red', \
#            label='UFD1, RT, z=0.373')
#
# plt.scatter(np.log10(mass_2_noRT_024), disp_2_noRT_024, marker='s', s=150, edgecolor='black', alpha=0.6, color='plum', \
#            label='UFD2, no RT, z=0.024')
# plt.scatter(np.log10(mass_2_noRT_130), disp_2_noRT_130, marker='s', s=150, edgecolor='black', alpha=0.6, color='violet', \
#            label='UFD2, no RT, z=0.130')
# plt.scatter(np.log10(mass_2_noRT_373), disp_2_noRT_373, marker='s', s=150, edgecolor='black', alpha=0.6, color='purple', \
#            label='UFD2, no RT, z=0.373')
#
# plt.scatter(np.log10(mass_2_RT_024), disp_2_RT_024, marker='v', s=150, edgecolor='black', alpha=0.6, color='plum', \
#            label='UFD2, RT, z=0.024')
# plt.scatter(np.log10(mass_2_RT_130), disp_2_RT_130, marker='v', s=150, edgecolor='black', alpha=0.6, color='violet', \
#            label='UFD2, RT, z=0.130')
# plt.scatter(np.log10(mass_2_RT_373), disp_2_RT_373, marker='v', s=150, edgecolor='black', alpha=0.6, color='purple', \
#            label='UFD2, RT, z=0.373')
#
# m_UFD = np.log10([0.0037e6, 0.0041e6, 0.0079e6, 0.014e6, 0.029e6, 0.037e6, 0.23e6])
# disp_UFD = [4.0, 6.46, 3.88, 7.93, 5.16, 5.49, 7.67]
# m_dSph = np.log10([0.29e6, 0.29e6, 0.38e6, 0.44e6, 0.74e6, 2.3e6, 3.5e6, 5.5e6, 20e6])
# disp_dSph = [9.05, 9.02, 6.44, 7.10, 6.76, 8.79, 7.68, 8.99, 10.59]
# plt.scatter(m_UFD, disp_UFD, marker='^', s=150, edgecolor='black', alpha=0.6, color='blue', label='MW UFDs')
# plt.scatter(m_dSph, disp_dSph, marker='^', s=150, edgecolor='black', alpha=0.6, color='black', label='MW dSphs')
#
# plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1.01))
#
# plt.xlabel('log M$_{*}$ (M$_\odot$)')
# plt.ylabel('$\sigma_{Re}$ (km/s)')
#
# #plt.savefig('logMstarsigmaRe.png')

# %% [markdown]
# ### Reading the observational data: dispersion for r_half ======================
#
# disp_2_noRT_024 = #[2.48766629, 5.08996942, 3.86571103]
# mass_2_noRT_024 = [3051.31, 3051.31, 3051.31]
# disp_2_noRT_130 = #[2.39658914, 3.81738892, 2.74464025]
# mass_2_noRT_130 = [3051.3835, 3051.3835, 3051.3835]
# disp_2_noRT_373 = #[1.58252957, 1.66094801, 2.46906618]
# mass_2_noRT_373 = [3051.5635, 3051.5635, 3051.5635]
#
# disp_2_RT_024 = #[1.07893852, 1.64087336, 1.5180028]
# mass_2_RT_024 = [1101.5865, 1101.5865, 1101.5865]
# disp_2_RT_130 = #[1.32618683, 0.40673541, 1.64995959]
# mass_2_RT_130 = [1101.6125, 1101.6125, 1101.6125]
# disp_2_RT_373 = #[0.7314541, 1.77425895, 1.90133223]
# mass_2_RT_373 = [1101.6795, 1101.6795, 1101.6795]
#
# disp_1_noRT_130 = [4.10769403 3.50671934 5.16035769]
# mass_1_noRT_130 = [8769.3805, 8769.3805, 8769.3805]
# disp_1_noRT_245 = #[2.70584009, 2.98236331, 4.34674925]
# mass_1_noRT_245 = [8778.7385, 8778.7385, 8778.7385]
# disp_1_noRT_373 = #[3.3776112,  2.64701708, 4.18393678]
# mass_1_noRT_373 = [8778.983, 8778.983, 8778.983]
#
# disp_1_RT_130 = #[2.38012571, 4.2428974, 4.74243197]
# mass_1_RT_130 = [3247.371, 3247.371, 3247.371]
# disp_1_RT_245 = #[2.53880549, 2.51880705, 4.41490523]
# mass_1_RT_245 = [3247.452, 3247.452, 3247.452]
# disp_1_RT_373 = #[2.6331385,  2.12334853, 3.37743894]
# mass_1_RT_373 = [3247.549, 3247.549, 3247.549]
#
# #fig, ax = plt.subplots(figsize=[9, 5])
#
# plt.scatter(np.log10(mass_1_noRT_130), disp_1_noRT_130, marker='P', s=150, edgecolor='black', alpha=0.6, color='yellow', \
#            label='UFD1, no RT, z=0.130')
# plt.scatter(np.log10(mass_1_noRT_245), disp_1_noRT_245, marker='P', s=150, edgecolor='black', alpha=0.6, color='orange', \
#            label='UFD1, no RT, z=0.245')
# plt.scatter(np.log10(mass_1_noRT_373), disp_1_noRT_373, marker='P', s=150, edgecolor='black', alpha=0.6, color='red', \
#            label='UFD1, no RT, z=0.373')
#
# plt.scatter(np.log10(mass_1_RT_130), disp_1_RT_130, marker='o', s=150, edgecolor='black', alpha=0.6, color='yellow', \
#            label='UFD1, RT, z=0.130')
# plt.scatter(np.log10(mass_1_RT_245), disp_1_RT_245, marker='o', s=150, edgecolor='black', alpha=0.6, color='orange', \
#            label='UFD1, RT, z=0.245')
# plt.scatter(np.log10(mass_1_RT_373), disp_1_RT_373, marker='o', s=150, edgecolor='black', alpha=0.6, color='red', \
#            label='UFD1, RT, z=0.373')
#
# plt.scatter(np.log10(mass_2_noRT_024), disp_2_noRT_024, marker='s', s=150, edgecolor='black', alpha=0.6, color='plum', \
#            label='UFD2, no RT, z=0.024')
# plt.scatter(np.log10(mass_2_noRT_130), disp_2_noRT_130, marker='s', s=150, edgecolor='black', alpha=0.6, color='violet', \
#            label='UFD2, no RT, z=0.130')
# plt.scatter(np.log10(mass_2_noRT_373), disp_2_noRT_373, marker='s', s=150, edgecolor='black', alpha=0.6, color='purple', \
#            label='UFD2, no RT, z=0.373')
#
# plt.scatter(np.log10(mass_2_RT_024), disp_2_RT_024, marker='v', s=150, edgecolor='black', alpha=0.6, color='plum', \
#            label='UFD2, RT, z=0.024')
# plt.scatter(np.log10(mass_2_RT_130), disp_2_RT_130, marker='v', s=150, edgecolor='black', alpha=0.6, color='violet', \
#            label='UFD2, RT, z=0.130')
# plt.scatter(np.log10(mass_2_RT_373), disp_2_RT_373, marker='v', s=150, edgecolor='black', alpha=0.6, color='purple', \
#            label='UFD2, RT, z=0.373')
#
# m_UFD = np.log10([0.0037e6, 0.0041e6, 0.0079e6, 0.014e6, 0.029e6, 0.037e6, 0.23e6])
# disp_UFD = [4.0, 6.46, 3.88, 7.93, 5.16, 5.49, 7.67]
# m_dSph = np.log10([0.29e6, 0.29e6, 0.38e6, 0.44e6, 0.74e6, 2.3e6, 3.5e6, 5.5e6, 20e6])
# disp_dSph = [9.05, 9.02, 6.44, 7.10, 6.76, 8.79, 7.68, 8.99, 10.59]
# plt.scatter(m_UFD, disp_UFD, marker='^', s=150, edgecolor='black', alpha=0.6, color='blue', label='MW UFDs')
# plt.scatter(m_dSph, disp_dSph, marker='^', s=150, edgecolor='black', alpha=0.6, color='black', label='MW dSphs')
#
# plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1.01))
#
# plt.xlabel('log M$_{*}$ (M$_\odot$)')
# plt.ylabel('$\sigma_{r1/2}$ (km/s)')
#
# #plt.savefig('logMstarsigmar12.png')
