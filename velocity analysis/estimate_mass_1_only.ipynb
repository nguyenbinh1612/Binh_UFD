# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %%
r_half = np.array([0.19, 0.17, 0.25, 0.17, 0.17, 0.17])
M_half_star = np.array([8769.38, 3247.37, 8778.7385, 3247.452, 8778.983, 3247.549])
M_half_DM = np.array([5995000.0, 4535000.0, \
                      9466500.0, 4506500.0, \
                      5061000.0, 4539500.0])
M_half_x_wolf = np.array([2236205.3571132086, 582081.1366890047, \
                          1355633.5503507145, 703888.802136308, \
                          1352789.2526943558, 605406.630980531])
M_half_y_wolf = np.array([1629737.0101335943, 1930836.9750556424, \
                          1573366.8060069934, 847161.9931007092, \
                          830853.2407428591, 212350.50146418586])
M_half_z_wolf = np.array([3529190.6750358306, 2505361.028889648, \
                          3406242.879232393, 2136784.3211826505, \
                          2075778.7370514057, 2075778.7370514057])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo1noRT130, = ax.plot('no RT,\nz = 0.130', M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo1RT130, = ax.plot('with RT,\nz = 0.130', M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo1noRT245, = ax.plot('no RT,\nz = 0.245', M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo1RT245, = ax.plot('with RT,\nz = 0.245', M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo1noRT373, = ax.plot('no RT,\nz = 0.373', M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_x_wolf[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_y_wolf[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_z_wolf[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo1RT373, = ax.plot('with RT,\nz = 0.373', M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_x_wolf[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_y_wolf[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_z_wolf[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

#plt.xlabel('redshift', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')

#first_legend = ax.legend(handles=[halo1noRT130, halo1noRT245, halo1noRT373,\
#                                  halo1RT130, halo1RT245, halo1RT373], fontsize=16, loc='upper center')

#ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=14, loc='lower center')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$, dwarf 1', \
         fontsize=19)

plt.yscale('log')

#plt.show()

plt.savefig('ratioplot1Wolf.png')

# %%
M_half_x_walker = np.array([1541867.7963305372, 418578.0527823788, \
                          848552.0629954358, 507412.1508920949, \
                          708953.7557400325, 605406.630980531])
M_half_y_walker = np.array([1070227.0577012817, 1466376.034829328, \
                          921451.6665921428, 620825.3707414055, \
                          518248.84553359763, 212350.50146418586])
M_half_z_walker = np.array([2280417.3366275816, 793258.0212926455, \
                          1898581.9503871836, 1477701.5294710137, \
                          1292943.4241380054, 515391.87696915126])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo1noRT130, = ax.plot('no RT,\nz = 0.130', M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_x_walker[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_y_walker[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_z_walker[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo1RT130, = ax.plot('with RT,\nz = 0.130', M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_x_walker[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_y_walker[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_z_walker[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo1noRT245, = ax.plot('no RT,\nz = 0.245', M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_x_walker[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_y_walker[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.245', M_half_z_walker[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo1RT245, = ax.plot('with RT,\nz = 0.245', M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_x_walker[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_y_walker[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.245', M_half_z_walker[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo1noRT373, = ax.plot('no RT,\nz = 0.373', M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_x_walker[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_y_walker[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_z_walker[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo1RT373, = ax.plot('with RT,\nz = 0.373', M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_x_walker[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_y_walker[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_z_walker[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

#plt.xlabel('redshift', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='Walker, x')
patch3 = mpatches.Patch(color='#DA4167', label='Walker, y')
patch4 = mpatches.Patch(color='#F4D35E', label='Walker, z')

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=14, loc='upper center')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$, dwarf 1', \
         fontsize=19)

plt.yscale('log')

#plt.show()

plt.savefig('ratioplot1Walker.png')
