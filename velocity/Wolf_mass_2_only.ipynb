# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %% [markdown]
# r_half = np.array([0.17, 0.13, 0.49, 0.05])
# M_half_star = np.array([8779.301, 3247.6735, 3051.688, 1101.59])
# M_half_DM = np.array([5116500, 2939000, 14014000, 357000])
# M_half_x_wolf = np.array([1968934.751, 1165376.999, 847206.2754, 79233.88201])
# M_half_y_wolf = np.array([878251.727, 896219.1646, 3858987.116, 11695.22367])
# M_half_z_wolf = np.array([1939348.312, 4373286.711, 2054710.263, 134120.7022])

# %% [markdown]
# fig, ax = plt.subplots(figsize=[10, 10])
#
# halo1noRT, = ax.plot(M_half_star[0], M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11, \
#                      label='dwarf 1 no RT, z = 0.514')
# plt.plot(M_half_star[0], M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
# plt.plot(M_half_star[0], M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
# plt.plot(M_half_star[0], M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)
#
# halo1RT, = ax.plot(M_half_star[1], M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11, \
#                    label='dwarf 1 RT, z = 0.514')
# plt.plot(M_half_star[1], M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
# plt.plot(M_half_star[1], M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
# plt.plot(M_half_star[1], M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)
#
# halo2noRT, = ax.plot(M_half_star[2], M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11, \
#                      label='dwarf 2 no RT, z = 0.514')
# plt.plot(M_half_star[2], M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
# plt.plot(M_half_star[2], M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
# plt.plot(M_half_star[2], M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)
#
# halo2RT, = ax.plot(M_half_star[3], M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11, \
#                    label='dwarf 2 RT, z = 0.514')
# plt.plot(M_half_star[3], M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
# plt.plot(M_half_star[3], M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
# plt.plot(M_half_star[3], M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)
#
# plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
# plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!
#
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
# patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
# patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
# patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')
#
# first_legend = ax.legend(handles=[halo1noRT, halo1RT, halo2noRT, halo2RT], fontsize=18, loc='upper right')
#
# ax = plt.gca().add_artist(first_legend)
#
# plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=18, loc='lower right')
#
# plt.yscale('log')
#
# plt.show()

# %%
r_half = np.array([0.39, 0.03, 0.35, 0.03, 0.45, 0.05])
M_half_star = np.array([3051.31, 1101.5865, 3051.3835, 1101.6125000000002, \
                        3051.5635, 1101.6795])
M_half_DM = np.array([10123000.0, 160000.0, 8527500.0, 155000.0, \
                     12456000.0, 391500.0])
M_half_x_wolf = np.array([3089190.781650352, 67337.29219465695, 2255824.7839599466, 29172.327158269196, \
                         1048213.2780520278, 34499.5521867516])
M_half_y_wolf = np.array([7196143.469320373, 122024.63670394571, 5495895.437079059, 2656.5840870515476, \
                         2185611.0000920403, 376007.40682182787])
M_half_z_wolf = np.array([3669443.09423609, 132182.36648143412, 3632372.731598813, 51095.47071543165, \
                         1493760.1550576796, 214969.7365667651])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo2noRT024, = ax.plot('no RT,\nz = 0.024', M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo2RT024, = ax.plot('with RT,\nz = 0.024', M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo2noRT130, = ax.plot('no RT,\nz = 0.130', M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo2RT130, = ax.plot('with RT,\nz = 0.130', M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo2noRT373, = ax.plot('no RT,\nz = 0.373', M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_x_wolf[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_y_wolf[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_z_wolf[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo2RT373, = ax.plot('with RT,\nz = 0.373', M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_x_wolf[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_y_wolf[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_z_wolf[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

#plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')

#first_legend = ax.legend(handles=[halo2noRT024, halo2noRT130, halo2noRT373, \
#                                  halo2RT024, halo2RT130, halo2RT373], fontsize=16, loc='upper center')

#ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=16, loc='lower left')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$', \
         fontsize=19)

plt.yscale('log')

plt.show()
