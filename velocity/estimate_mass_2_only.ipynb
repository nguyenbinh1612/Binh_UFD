# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %%
r_half = np.array([0.39, 0.03, 0.35, 0.03, 0.45, 0.05])
M_half_star = np.array([3051.31, 1101.5865, 3051.3835, 1101.6125000000002, \
                        3051.5635, 1101.6795])
M_half_DM = np.array([10123000.0, 160000.0, 8527500.0, 155000.0, \
                     12456000.0, 391500.0])
M_half_x_wolf = np.array([1683490.845751138, 24359.95964744333, 1402223.1380631973, 36803.79358092147, \
                         786100.5289536082, 18659.760865209064])
M_half_y_wolf = np.array([7047853.432301694, 122024.63670394571, 3557646.31823891, 3461.8410749032246, \
                         865937.4063923194, 109790.79388693217])
M_half_z_wolf = np.array([4065231.569324859, 132182.36648143412, 1839080.7990740214, 56967.84369159322, \
                         1913550.3082653333, 126080.50385517976])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo2noRT024, = ax.plot('no RT,\nz = 0.024', M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo2RT024, = ax.plot('with RT,\nz = 0.024', M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo2noRT130, = ax.plot('no RT,\nz = 0.130', M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo2RT130, = ax.plot('with RT,\nz = 0.130', M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo2noRT373, = ax.plot('no RT,\nz = 0.373', M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_x_wolf[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_y_wolf[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_z_wolf[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo2RT373, = ax.plot('with RT,\nz = 0.373', M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_x_wolf[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_y_wolf[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_z_wolf[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

#plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')

#first_legend = ax.legend(handles=[halo2noRT024, halo2noRT130, halo2noRT373, \
#                                  halo2RT024, halo2RT130, halo2RT373], fontsize=16, loc='upper center')

#ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=14, loc='lower left')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$, dwarf 2', \
         fontsize=19)

plt.yscale('log')

plt.show()

# %%
M_half_x_walker = np.array([1221381.4592299748, 15224.974779652084, \
                          955854.7387863125, 23002.370988075916, \
                          222575.34363456944, 2661.489469415546])
M_half_y_walker = np.array([463358.7260361514, 35213.83397855831, \
                          847259.5005030527, 2163.6506718145156, \
                          398030.61992984265, 60235.841085566164])
M_half_z_walker = np.array([679146.083106552, 30137.576397205466, \
                          416934.56983168324, 35604.902307245764, \
                          647234.1942745384, 10927.588206813507])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo2noRT024, = ax.plot('no RT,\nz = 0.024', M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_x_walker[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_y_walker[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.024', M_half_z_walker[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo2RT024, = ax.plot('with RT,\nz = 0.024', M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_x_walker[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_y_walker[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.024', M_half_z_walker[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo2noRT130, = ax.plot('no RT,\nz = 0.130', M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_x_walker[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_y_walker[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.130', M_half_z_walker[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo2RT130, = ax.plot('with RT,\nz = 0.130', M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_x_walker[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_y_walker[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.130', M_half_z_walker[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo2noRT373, = ax.plot('no RT,\nz = 0.373', M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_x_walker[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_y_walker[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot('no RT,\nz = 0.373', M_half_z_walker[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo2RT373, = ax.plot('with RT,\nz = 0.373', M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_x_walker[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_y_walker[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot('with RT,\nz = 0.373', M_half_z_walker[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

#plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='walker, x')
patch3 = mpatches.Patch(color='#DA4167', label='walker, y')
patch4 = mpatches.Patch(color='#F4D35E', label='walker, z')

#first_legend = ax.legend(handles=[halo2noRT024, halo2noRT130, halo2noRT373, \
#                                  halo2RT024, halo2RT130, halo2RT373], fontsize=16, loc='upper center')

#ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=14, loc='lower left')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$, dwa', \
         fontsize=19)

plt.yscale('log')

plt.show()
