# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %% [markdown]
# r_half = np.array([0.19, 0.15, 0.39, 0.03])
# M_half_star = np.array([8769.38, 3247.37, 3051.31, 1101.59])
# M_half_DM = np.array([5.99e6, 3.69e6, 1.01e7, 1.6e5])
# M_half_x_wolf = np.array([1.48e6, 5.93e5, 3.1e6, 6.73e4])
# M_half_y_wolf = np.array([1.37e6, 1.76e6, 7.2e6, 1.22e5])
# M_half_z_wolf = np.array([4.45e6, 2.7e6, 3.67e6, 1.32e5])

# %% [markdown]
# fig, ax = plt.subplots(figsize=[10, 10])
#
# halo1noRT, = ax.plot(M_half_star[0], M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11, \
#                      label='dwarf 1 no RT, z = 0.130')
# plt.plot(M_half_star[0], M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
# plt.plot(M_half_star[0], M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
# plt.plot(M_half_star[0], M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)
#
# halo1RT, = ax.plot(M_half_star[1], M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11, \
#                    label='dwarf 1 RT, z = 0.130')
# plt.plot(M_half_star[1], M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
# plt.plot(M_half_star[1], M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
# plt.plot(M_half_star[1], M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)
#
# halo2noRT, = ax.plot(M_half_star[2], M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11, \
#                      label='dwarf 2 no RT, z = 0.024')
# plt.plot(M_half_star[2], M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
# plt.plot(M_half_star[2], M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
# plt.plot(M_half_star[2], M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)
#
# halo2RT, = ax.plot(M_half_star[3], M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11, \
#                    label='dwarf 2 RT, z = 0.024')
# plt.plot(M_half_star[3], M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
# plt.plot(M_half_star[3], M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
# plt.plot(M_half_star[3], M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)
#
# plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
# plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!
#
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
# patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
# patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
# patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')
#
# first_legend = ax.legend(handles=[halo1noRT, halo1RT, halo2noRT, halo2RT], fontsize=18, loc='upper right')
#
# ax = plt.gca().add_artist(first_legend)
#
# plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=18, loc='lower right')
#
# plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$ at most recent redshifts', \
#          fontsize=19)
#
# plt.yscale('log')
#
# plt.show()

# %%
r_half = np.array([0.19, 0.15, 0.17, 0.15, 0.17, 0.21])
M_half_star = np.array([8769.38, 3247.37, 8778.7385, 3247.452, 8778.983, 3247.549])
M_half_DM = np.array([5995000.0, 3682500.0, \
                      5112500.0, 3677500.0, \
                      5061000.0, 6432000.0])
M_half_x_wolf = np.array([1484623.929407372, 592688.1122555746, \
                          1018104.3424864563, 757363.4500918413, \
                          2328488.0220244713, 988456.7188779607])
M_half_y_wolf = np.array([1369823.1870004914, 1762182.431700342, \
                          1158556.796724232, 612603.230602897, \
                          979802.3398616216, 651302.5573458787])
M_half_z_wolf = np.array([4450940.868914964, 2697603.4918272914, \
                          4341462.574466971, 1917399.5048710739, \
                          2823907.1103185914, 1870899.319263926])

# %%
fig, ax = plt.subplots(figsize=[10, 10])

halo1noRT130, = ax.plot(M_half_star[0], M_half_DM[0] / M_half_star[0], 's', color='#3185FC', markersize=11, \
                     label='dwarf 1 no RT, z = 0.130')
plt.plot(M_half_star[0], M_half_x_wolf[0] / M_half_star[0], 's', color='#083D77', markersize=11)
plt.plot(M_half_star[0], M_half_y_wolf[0] / M_half_star[0], 's', color='#DA4167', markersize=11)
plt.plot(M_half_star[0], M_half_z_wolf[0] / M_half_star[0], 's', color='#F4D35E', markersize=11)

halo1noRT245, = ax.plot(M_half_star[2], M_half_DM[2] / M_half_star[2], 'o', color='#3185FC', markersize=11, \
                     label='dwarf 1 no RT, z = 0.245')
plt.plot(M_half_star[2], M_half_x_wolf[2] / M_half_star[2], 'o', color='#083D77', markersize=11)
plt.plot(M_half_star[2], M_half_y_wolf[2] / M_half_star[2], 'o', color='#DA4167', markersize=11)
plt.plot(M_half_star[2], M_half_z_wolf[2] / M_half_star[2], 'o', color='#F4D35E', markersize=11)

halo1noRT373, = ax.plot(M_half_star[4], M_half_DM[4] / M_half_star[4], 'd', color='#3185FC', markersize=11, \
                     label='dwarf 1 no RT, z = 0.373')
plt.plot(M_half_star[4], M_half_x_wolf[4] / M_half_star[4], 'd', color='#083D77', markersize=11)
plt.plot(M_half_star[4], M_half_y_wolf[4] / M_half_star[4], 'd', color='#DA4167', markersize=11)
plt.plot(M_half_star[4], M_half_z_wolf[4] / M_half_star[4], 'd', color='#F4D35E', markersize=11)

halo1RT130, = ax.plot(M_half_star[1], M_half_DM[1] / M_half_star[1], '^', color='#3185FC', markersize=11, \
                   label='dwarf 1 RT, z = 0.130')
plt.plot(M_half_star[1], M_half_x_wolf[1] / M_half_star[1], '^', color='#083D77', markersize=11)
plt.plot(M_half_star[1], M_half_y_wolf[1] / M_half_star[1], '^', color='#DA4167', markersize=11)
plt.plot(M_half_star[1], M_half_z_wolf[1] / M_half_star[1], '^', color='#F4D35E', markersize=11)

halo1RT245, = ax.plot(M_half_star[3], M_half_DM[3] / M_half_star[3], 'P', color='#3185FC', markersize=11, \
                   label='dwarf 1 RT, z = 0.245')
plt.plot(M_half_star[3], M_half_x_wolf[3] / M_half_star[3], 'P', color='#083D77', markersize=11)
plt.plot(M_half_star[3], M_half_y_wolf[3] / M_half_star[3], 'P', color='#DA4167', markersize=11)
plt.plot(M_half_star[3], M_half_z_wolf[3] / M_half_star[3], 'P', color='#F4D35E', markersize=11)

halo1RT373, = ax.plot(M_half_star[5], M_half_DM[5] / M_half_star[5], 'h', color='#3185FC', markersize=11, \
                   label='dwarf 1 RT, z = 0.373')
plt.plot(M_half_star[5], M_half_x_wolf[5] / M_half_star[5], 'h', color='#083D77', markersize=11)
plt.plot(M_half_star[5], M_half_y_wolf[5] / M_half_star[5], 'h', color='#DA4167', markersize=11)
plt.plot(M_half_star[5], M_half_z_wolf[5] / M_half_star[5], 'h', color='#F4D35E', markersize=11)

plt.xlabel('M$_{half,stars}$ (M$_\odot$)', fontsize=17)
plt.ylabel(r'$\frac{M_{half,DM}}{M_{half,stars}}$', fontsize=24) # using LATEX here!

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
patch1 = mpatches.Patch(color='#3185FC', label='DM halo')
patch2 = mpatches.Patch(color='#083D77', label='Wolf, x')
patch3 = mpatches.Patch(color='#DA4167', label='Wolf, y')
patch4 = mpatches.Patch(color='#F4D35E', label='Wolf, z')

first_legend = ax.legend(handles=[halo1noRT130, halo1noRT245, halo1noRT373,\
                                  halo1RT130, halo1RT245, halo1RT373], fontsize=16, loc='upper center')

ax = plt.gca().add_artist(first_legend)

plt.legend(handles=[patch1, patch2, patch3, patch4], fontsize=16, loc='lower center')

plt.title('Ratio between M$_{half,DM}$ and M$_{half,stars}$\nwith respect to M$_{half,stars}$', \
         fontsize=19)

plt.yscale('log')

plt.show()
