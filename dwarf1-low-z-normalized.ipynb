# %%
# all the density stuff for low z measurements of dwarf 1, normalized.

# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

from IPython.display import Latex

# %matplotlib inline

from NFW import NFW

# %%
dr = 10

# %%
'''THIS PART IS FOR DWARF 1 WITH RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITH RT'

# %%
전data180 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0180.txt")
dx180 = 전data180[:,4]
dy180 = 전data180[:,5]
dz180 = 전data180[:,6]
r180 = np.sqrt(dx180**2 + dy180**2 + dz180**2) # max: 4762.8993529580275, closest to 4770
rad_array180 = np.arange(10, 4770, dr, dtype=np.int64)
density_profile180 = np.zeros(np.size(rad_array180))
i = 0
for radius_value in rad_array180:
    particles = np.where((r180 > radius_value) & (r180 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile180[i] = how_many_particles / shell_volume
    i += 1
densityprof180 = density_profile180 / density_profile180[0]

# %%
전data160 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0160.txt")
dx160 = 전data160[:,4]
dy160 = 전data160[:,5]
dz160 = 전data160[:,6]
r160 = np.sqrt(dx160**2 + dy160**2 + dz160**2) # max: 3765.12861331959, closest to 3770
rad_array160 = np.arange(10, 3770, dr, dtype=np.int64)
density_profile160 = np.zeros(np.size(rad_array160))
i = 0
for radius_value in rad_array160:
    particles = np.where((r160 > radius_value) & (r160 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile160[i] = how_many_particles / shell_volume
    i += 1
densityprof160 = density_profile160 / density_profile160[0]

# %%
전data140 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0140.txt")
dx140 = 전data140[:,4]
dy140 = 전data140[:,5]
dz140 = 전data140[:,6]
r140 = np.sqrt(dx140**2 + dy140**2 + dz140**2) # max: 2476.225440569174, closest to 2480
rad_array140 = np.arange(10, 2480, dr, dtype=np.int64)
density_profile140 = np.zeros(np.size(rad_array140))
i = 0
for radius_value in rad_array140:
    particles = np.where((r140 > radius_value) & (r140 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile140[i] = how_many_particles / shell_volume
    i += 1
densityprof140 = density_profile140 / density_profile140[0]

# %%
전data120 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0120.txt")
dx120 = 전data120[:,4]
dy120 = 전data120[:,5]
dz120 = 전data120[:,6]
r120 = np.sqrt(dx120**2 + dy120**2 + dz120**2) # max: 1839.3927923251765, closest to 1840
rad_array120 = np.arange(10, 1840, dr, dtype=np.int64)
density_profile120 = np.zeros(np.size(rad_array120))
i = 0
for radius_value in rad_array120:
    particles = np.where((r120 > radius_value) & (r120 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile120[i] = how_many_particles / shell_volume
    i += 1
densityprof120 = density_profile120 / density_profile120[0]

# %%
전data100 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0100.txt")
dx100 = 전data100[:,4]
dy100 = 전data100[:,5]
dz100 = 전data100[:,6]
r100 = np.sqrt(dx100**2 + dy100**2 + dz100**2) # max: 1216.640092340962, closest to 1220
rad_array100 = np.arange(10, 1220, dr, dtype=np.int64)
density_profile100 = np.zeros(np.size(rad_array100))
i = 0
for radius_value in rad_array100:
    particles = np.where((r100 > radius_value) & (r100 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile100[i] = how_many_particles / shell_volume
    i += 1
densityprof100 = density_profile100 / density_profile100[0]

# %%
'''THIS PART IS FOR DWARF 1 WITHOUT RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITHOUT RT'

# %%
전data170 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0170.txt")
dx170 = 전data170[:,4]
dy170 = 전data170[:,5]
dz170 = 전data170[:,6]
r170 = np.sqrt(dx170**2 + dy170**2 + dz170**2) # max: 4540.972105566934, closest to 4560
rad_array170 = np.arange(10, 4560, dr, dtype=np.int64)
density_profile170 = np.zeros(np.size(rad_array170))
i = 0
for radius_value in rad_array170:
    particles = np.where((r170 > radius_value) & (r170 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile170[i] = how_many_particles / shell_volume
    i += 1
densityprof170 = density_profile170 / density_profile170[0]

# %%
전data150 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0150.txt")
dx150 = 전data150[:,4]
dy150 = 전data150[:,5]
dz150 = 전data150[:,6]
r150 = np.sqrt(dx150**2 + dy150**2 + dz150**2) # max: 2712.6740860997293, closest to 2760
rad_array150 = np.arange(10, 2760, dr, dtype=np.int64)
density_profile150 = np.zeros(np.size(rad_array150))
i = 0
for radius_value in rad_array150:
    particles = np.where((r150 > radius_value) & (r150 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile150[i] = how_many_particles / shell_volume
    i += 1
densityprof150 = density_profile150 / density_profile150[0]

# %%
전data130 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0130.txt")
dx130 = 전data130[:,4]
dy130 = 전data130[:,5]
dz130 = 전data130[:,6]
r130 = np.sqrt(dx130**2 + dy130**2 + dz130**2) # max: 2218.0197067752147, closest to 2220
rad_array130 = np.arange(10, 2220, dr, dtype=np.int64)
density_profile130 = np.zeros(np.size(rad_array130))
i = 0
for radius_value in rad_array130:
    particles = np.where((r130 > radius_value) & (r130 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile130[i] = how_many_particles / shell_volume
    i += 1
densityprof130 = density_profile130 / density_profile130[0]

# %%
전data110 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0110.txt")
dx110 = 전data110[:,4]
dy110 = 전data110[:,5]
dz110 = 전data110[:,6]
r110 = np.sqrt(dx110**2 + dy110**2 + dz110**2) # max: 1431.4151120109009, closest to 1440
rad_array110 = np.arange(10, 1440, dr, dtype=np.int64)
density_profile110 = np.zeros(np.size(rad_array110))
i = 0
for radius_value in rad_array110:
    particles = np.where((r110 > radius_value) & (r110 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile110[i] = how_many_particles / shell_volume
    i += 1
densityprof110 = density_profile110 / density_profile110[0]

# %%
전data90 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0090.txt")
dx90 = 전data90[:,4]
dy90 = 전data90[:,5]
dz90 = 전data90[:,6]
r90 = np.sqrt(dx90**2 + dy90**2 + dz90**2) # max: 937.9463670274597, closest to 960
rad_array90 = np.arange(10, 960, dr, dtype=np.int64)
density_profile90 = np.zeros(np.size(rad_array90))
i = 0
for radius_value in rad_array90:
    particles = np.where((r90 > radius_value) & (r90 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile90[i] = how_many_particles / shell_volume
    i += 1
densityprof90 = density_profile90 / density_profile90[0]

# %%
전data70 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0070.txt")
dx70 = 전data70[:,4]
dy70 = 전data70[:,5]
dz70 = 전data70[:,6]
r70 = np.sqrt(dx70**2 + dy70**2 + dz70**2) # max: 576.1232123555365, closest to 600
rad_array70 = np.arange(10, 600, dr, dtype=np.int64)
density_profile70 = np.zeros(np.size(rad_array70))
i = 0
for radius_value in rad_array70:
    particles = np.where((r70 > radius_value) & (r70 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile70[i] = how_many_particles / shell_volume
    i += 1
densityprof70 = density_profile70 / density_profile70[0]

# %%
plt.figure(figsize=(13,13))

# dwarf1_RT.txt

plt.plot(rad_array170, densityprof170, color=(0.5, 0.1, 0.9, 0.48), linewidth=2)
plt.plot(rad_array150, densityprof150, color=(0.5, 0.1, 0.9, 0.42), linewidth=2)
plt.plot(rad_array130, densityprof130, color=(0.5, 0.1, 0.9, 0.38), linewidth=2)
plt.plot(rad_array110, densityprof110, color=(0.5, 0.1, 0.9, 0.36), linewidth=2)
plt.plot(rad_array90, densityprof90, color=(0.5, 0.1, 0.9, 0.28), linewidth=2)
plt.plot(rad_array70, densityprof70, color=(0.5, 0.1, 0.9, 0.26), linewidth=2)

purple6 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.48), label='z = 2.648')
purple5 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.42), label='z = 3.435')
purple4 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.38), label='z = 4.392')
purple3 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.36), label='z = 5.555')
purple2 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.28), label='z = 6.969')
purple1 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.26), label='z = 8.689')

# dwarf1_noRT.txt

plt.plot(rad_array180, densityprof180, color=(0.2, 0.9, 0.6, 0.48), linewidth=2)
plt.plot(rad_array160, densityprof160, color=(0.2, 0.9, 0.6, 0.42), linewidth=2)
plt.plot(rad_array140, densityprof140, color=(0.2, 0.9, 0.6, 0.38), linewidth=2)
plt.plot(rad_array120, densityprof120, color=(0.2, 0.9, 0.6, 0.36), linewidth=2)
plt.plot(rad_array100, densityprof100, color=(0.2, 0.9, 0.6, 0.28), linewidth=2)

green5 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.48), label='z = 2.308')
green4 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.42), label='z = 3.022')
green3 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.38), label='z = 3.890')
green2 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.36), label='z = 4.945')
green1 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.28), label='z = 6.228')

first_legend = plt.legend(handles=[green5, green4, green3, \
                                   green2, green1],loc='upper right')
plt.gca().add_artist(first_legend)
second_legend = plt.legend(handles=[purple6, purple5, purple4, \
                                    purple3, purple2, purple1],loc='lower left')

plt.xlabel('distance from center of galaxy halo (pc)', fontsize=17)
plt.ylabel('normalized dark matter density', fontsize=17) # using LATEX here!
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(10,10**4.2)
plt.xscale('log')
plt.yscale('log')

plt.title('normalized dark matter density profiles of dwarf 1, low z,\nwith RT (green) and without RT (purple), bin size = ' \
          + str(dr), loc='center', fontsize=20)

plt.show()
