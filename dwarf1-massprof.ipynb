# %%
# all the density stuff for low z measurements of dwarf 1, UNnormalized.

# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

from IPython.display import Latex

# %matplotlib inline

# %%
dr = 10

# %%
'''THIS PART IS FOR DWARF 1 WITH RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITH RT'

# %%
전data290 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0290.txt")
dx290 = 전data290[:,4]
dy290 = 전data290[:,5]
dz290 = 전data290[:,6]
r290 = np.sqrt(dx290**2 + dy290**2 + dz290**2) # max: 11415.825965662318, closest to 11420
rad_array290 = np.arange(10, 11420, dr, dtype=np.int64)

density_profile290 = np.zeros(np.size(rad_array290))
i = 0
for radius_value in rad_array290:
    particles = np.where((r290 > radius_value) & (r290 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile290[i] = how_many_particles / shell_volume
    i += 1

mass_profile290 = np.zeros(np.size(rad_array290))
h = 0
for radius_value in rad_array290:
    particles = np.where((r290 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile290[h] = how_many_particles * 500
    h += 1

# %%
전data280 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0280.txt")
dx280 = 전data280[:,4]
dy280 = 전data280[:,5]
dz280 = 전data280[:,6]
r280 = np.sqrt(dx280**2 + dy280**2 + dz280**2) # max: 10873.03722354305, closest to 10880
rad_array280 = np.arange(10, 10880, dr, dtype=np.int64)

density_profile280 = np.zeros(np.size(rad_array280))
i = 0
for radius_value in rad_array280:
    particles = np.where((r280 > radius_value) & (r280 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile280[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile280 = np.zeros(np.size(rad_array280))
h = 0
for radius_value in rad_array280:
    particles = np.where((r280 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile280[h] = how_many_particles * 500
    h += 1

# %%
전data270 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0270.txt")
dx270 = 전data270[:,4]
dy270 = 전data270[:,5]
dz270 = 전data270[:,6]
r270 = np.sqrt(dx270**2 + dy270**2 + dz270**2) # max: 10304.377486889249, closest to 10310
rad_array270 = np.arange(10, 10310, dr, dtype=np.int64)

density_profile270 = np.zeros(np.size(rad_array270))
i = 0
for radius_value in rad_array270:
    particles = np.where((r270 > radius_value) & (r270 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile270[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile270 = np.zeros(np.size(rad_array270))
h = 0
for radius_value in rad_array270:
    particles = np.where((r270 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile270[h] = how_many_particles * 500
    h += 1

# %%
전data260 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0260.txt")
dx260 = 전data260[:,4]
dy260 = 전data260[:,5]
dz260 = 전data260[:,6]
r260 = np.sqrt(dx260**2 + dy260**2 + dz260**2) # max: 9736.070358548308, closest to 9740
rad_array260 = np.arange(10, 9740, dr, dtype=np.int64)

density_profile260 = np.zeros(np.size(rad_array260))
i = 0
for radius_value in rad_array260:
    particles = np.where((r260 > radius_value) & (r260 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile260[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile260 = np.zeros(np.size(rad_array260))
h = 0
for radius_value in rad_array260:
    particles = np.where((r260 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile260[h] = how_many_particles * 500
    h += 1

# %%
전data250 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0250.txt")
dx250 = 전data250[:,4]
dy250 = 전data250[:,5]
dz250 = 전data250[:,6]
r250 = np.sqrt(dx250**2 + dy250**2 + dz250**2) # max: 9092.83786101821, closest to 9100
rad_array250 = np.arange(10, 9100, dr, dtype=np.int64)

density_profile250 = np.zeros(np.size(rad_array250))
i = 0
for radius_value in rad_array250:
    particles = np.where((r250 > radius_value) & (r250 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile250[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile250 = np.zeros(np.size(rad_array250))
h = 0
for radius_value in rad_array250:
    particles = np.where((r250 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile250[h] = how_many_particles * 500
    h += 1

# %%
전data240 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0240.txt")
dx240 = 전data240[:,4]
dy240 = 전data240[:,5]
dz240 = 전data240[:,6]
r240 = np.sqrt(dx240**2 + dy240**2 + dz240**2) # max: 8463.430201041538, closest to 8470
rad_array240 = np.arange(10, 8470, dr, dtype=np.int64)

density_profile240 = np.zeros(np.size(rad_array240))
i = 0
for radius_value in rad_array240:
    particles = np.where((r240 > radius_value) & (r240 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile240[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile240 = np.zeros(np.size(rad_array240))
h = 0
for radius_value in rad_array240:
    particles = np.where((r240 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile240[h] = how_many_particles * 500
    h += 1

# %%
전data230 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0230.txt")
dx230 = 전data230[:,4]
dy230 = 전data230[:,5]
dz230 = 전data230[:,6]
r230 = np.sqrt(dx230**2 + dy230**2 + dz230**2) # max: 7816.878257007077, closest to 7820
rad_array230 = np.arange(10, 7820, dr, dtype=np.int64)

density_profile230 = np.zeros(np.size(rad_array230))
i = 0
for radius_value in rad_array230:
    particles = np.where((r230 > radius_value) & (r230 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile230[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile230 = np.zeros(np.size(rad_array230))
h = 0
for radius_value in rad_array230:
    particles = np.where((r230 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile230[h] = how_many_particles * 500
    h += 1

# %%
전data220 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0220.txt")
dx220 = 전data220[:,4]
dy220 = 전data220[:,5]
dz220 = 전data220[:,6]
r220 = np.sqrt(dx220**2 + dy220**2 + dz220**2) # max: 7069.6147688487945, closest to 7070
rad_array220 = np.arange(10, 7070, dr, dtype=np.int64)

density_profile220 = np.zeros(np.size(rad_array220))
i = 0
for radius_value in rad_array220:
    particles = np.where((r220 > radius_value) & (r220 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile220[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile220 = np.zeros(np.size(rad_array220))
h = 0
for radius_value in rad_array220:
    particles = np.where((r220 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile220[h] = how_many_particles * 500
    h += 1

# %%
전data210 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0210.txt")
dx210 = 전data210[:,4]
dy210 = 전data210[:,5]
dz210 = 전data210[:,6]
r210 = np.sqrt(dx210**2 + dy210**2 + dz210**2) # max: 6403.483270570543, closest to 6410
rad_array210 = np.arange(10, 6410, dr, dtype=np.int64)

density_profile210 = np.zeros(np.size(rad_array210))
i = 0
for radius_value in rad_array210:
    particles = np.where((r210 > radius_value) & (r210 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile210[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile210 = np.zeros(np.size(rad_array210))
h = 0
for radius_value in rad_array210:
    particles = np.where((r210 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile210[h] = how_many_particles * 500
    h += 1

# %%
전data200 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0200.txt")
dx200 = 전data200[:,4]
dy200 = 전data200[:,5]
dz200 = 전data200[:,6]
r200 = np.sqrt(dx200**2 + dy200**2 + dz200**2) # max: 5758.806829615749, closest to 5760
rad_array200 = np.arange(10, 5760, dr, dtype=np.int64)

density_profile200 = np.zeros(np.size(rad_array200))
i = 0
for radius_value in rad_array200:
    particles = np.where((r200 > radius_value) & (r200 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile200[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile200 = np.zeros(np.size(rad_array200))
h = 0
for radius_value in rad_array200:
    particles = np.where((r200 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile200[h] = how_many_particles * 500
    h += 1

# %%
전data190 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0190.txt")
dx190 = 전data190[:,4]
dy190 = 전data190[:,5]
dz190 = 전data190[:,6]
r190 = np.sqrt(dx190**2 + dy190**2 + dz190**2) # max: 5113.111121256088, closest to 5120
rad_array190 = np.arange(10, 5120, dr, dtype=np.int64)

density_profile190 = np.zeros(np.size(rad_array190))
i = 0
for radius_value in rad_array190:
    particles = np.where((r190 > radius_value) & (r190 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile190[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile190 = np.zeros(np.size(rad_array190))
h = 0
for radius_value in rad_array190:
    particles = np.where((r190 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile190[h] = how_many_particles * 500
    h += 1

# %%
전data180 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0180.txt")
dx180 = 전data180[:,4]
dy180 = 전data180[:,5]
dz180 = 전data180[:,6]
r180 = np.sqrt(dx180**2 + dy180**2 + dz180**2) # max: 4762.8993529580275, closest to 4770
rad_array180 = np.arange(10, 4770, dr, dtype=np.int64)

density_profile180 = np.zeros(np.size(rad_array180))
i = 0
for radius_value in rad_array180:
    particles = np.where((r180 > radius_value) & (r180 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile180[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile180 = np.zeros(np.size(rad_array180))
h = 0
for radius_value in rad_array180:
    particles = np.where((r180 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile180[h] = how_many_particles * 500
    h += 1

# %%
전data170 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0170.txt")
dx170 = 전data170[:,4]
dy170 = 전data170[:,5]
dz170 = 전data170[:,6]
r170 = np.sqrt(dx170**2 + dy170**2 + dz170**2) # max: 4536.698931246264, closest to 4540
rad_array170 = np.arange(10, 4540, dr, dtype=np.int64)

density_profile170 = np.zeros(np.size(rad_array170))
i = 0
for radius_value in rad_array170:
    particles = np.where((r170 > radius_value) & (r170 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile170[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile170 = np.zeros(np.size(rad_array170))
h = 0
for radius_value in rad_array170:
    particles = np.where((r170 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile170[h] = how_many_particles * 500
    h += 1

# %%
전data160 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0160.txt")
dx160 = 전data160[:,4]
dy160 = 전data160[:,5]
dz160 = 전data160[:,6]
r160 = np.sqrt(dx160**2 + dy160**2 + dz160**2) # max: 3765.12861331959, closest to 3770
rad_array160 = np.arange(10, 3770, dr, dtype=np.int64)

density_profile160 = np.zeros(np.size(rad_array160))
i = 0
for radius_value in rad_array160:
    particles = np.where((r160 > radius_value) & (r160 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile160[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile160 = np.zeros(np.size(rad_array160))
h = 0
for radius_value in rad_array160:
    particles = np.where((r160 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile160[h] = how_many_particles * 500
    h += 1

# %%
전data150 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0150.txt")
dx150 = 전data150[:,4]
dy150 = 전data150[:,5]
dz150 = 전data150[:,6]
r150 = np.sqrt(dx150**2 + dy150**2 + dz150**2) # max: 2714.4716657988897, closest to 2720
rad_array150 = np.arange(10, 2720, dr, dtype=np.int64)

density_profile150 = np.zeros(np.size(rad_array150))
i = 0
for radius_value in rad_array150:
    particles = np.where((r150 > radius_value) & (r150 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile150[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile150 = np.zeros(np.size(rad_array150))
h = 0
for radius_value in rad_array150:
    particles = np.where((r150 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile150[h] = how_many_particles * 500
    h += 1

# %%
전data140 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0140.txt")
dx140 = 전data140[:,4]
dy140 = 전data140[:,5]
dz140 = 전data140[:,6]
r140 = np.sqrt(dx140**2 + dy140**2 + dz140**2) # max: 2476.225440569174, closest to 2480
rad_array140 = np.arange(10, 2480, dr, dtype=np.int64)

density_profile140 = np.zeros(np.size(rad_array140))
i = 0
for radius_value in rad_array140:
    particles = np.where((r140 > radius_value) & (r140 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile140[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile140 = np.zeros(np.size(rad_array140))
h = 0
for radius_value in rad_array140:
    particles = np.where((r140 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile140[h] = how_many_particles * 500
    h += 1

# %%
전data130 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0130.txt")
dx130 = 전data130[:,4]
dy130 = 전data130[:,5]
dz130 = 전data130[:,6]
r130 = np.sqrt(dx130**2 + dy130**2 + dz130**2) # max: 2234.732687333599, closest to 2240
rad_array130 = np.arange(10, 2240, dr, dtype=np.int64)

density_profile130 = np.zeros(np.size(rad_array130))
i = 0
for radius_value in rad_array130:
    particles = np.where((r130 > radius_value) & (r130 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile130[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile130 = np.zeros(np.size(rad_array130))
h = 0
for radius_value in rad_array130:
    particles = np.where((r130 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile130[h] = how_many_particles * 500
    h += 1

# %%
전data120 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0120.txt")
dx120 = 전data120[:,4]
dy120 = 전data120[:,5]
dz120 = 전data120[:,6]
r120 = np.sqrt(dx120**2 + dy120**2 + dz120**2) # max: 1839.3927923251765, closest to 1840
rad_array120 = np.arange(10, 1840, dr, dtype=np.int64)

density_profile120 = np.zeros(np.size(rad_array120))
i = 0
for radius_value in rad_array120:
    particles = np.where((r120 > radius_value) & (r120 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile120[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile120 = np.zeros(np.size(rad_array120))
h = 0
for radius_value in rad_array120:
    particles = np.where((r120 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile120[h] = how_many_particles * 500
    h += 1

# %%
전data110 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0110.txt")
dx110 = 전data110[:,4]
dy110 = 전data110[:,5]
dz110 = 전data110[:,6]
r110 = np.sqrt(dx110**2 + dy110**2 + dz110**2) # max: 1471.9733524340854, closest to 1480
rad_array110 = np.arange(10, 1480, dr, dtype=np.int64)

density_profile110 = np.zeros(np.size(rad_array110))
i = 0
for radius_value in rad_array110:
    particles = np.where((r110 > radius_value) & (r110 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile110[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile110 = np.zeros(np.size(rad_array110))
h = 0
for radius_value in rad_array110:
    particles = np.where((r110 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile110[h] = how_many_particles * 500
    h += 1

# %%
전data100 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0100.txt")
dx100 = 전data100[:,4]
dy100 = 전data100[:,5]
dz100 = 전data100[:,6]
r100 = np.sqrt(dx100**2 + dy100**2 + dz100**2) # max: 1216.640092340962, closest to 1220
rad_array100 = np.arange(10, 1220, dr, dtype=np.int64)

density_profile100 = np.zeros(np.size(rad_array100))
i = 0
for radius_value in rad_array100:
    particles = np.where((r100 > radius_value) & (r100 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile100[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile100 = np.zeros(np.size(rad_array100))
h = 0
for radius_value in rad_array100:
    particles = np.where((r100 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile100[h] = how_many_particles * 500
    h += 1

# %%
전data99 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0099.txt")
dx99 = 전data99[:,4]
dy99 = 전data99[:,5]
dz99 = 전data99[:,6]
r99 = np.sqrt(dx99**2 + dy99**2 + dz99**2) # max: 1191.7751355639955, closest to 1200
rad_array99 = np.arange(10, 1200, dr, dtype=np.int64)

density_profile99 = np.zeros(np.size(rad_array99))
i = 0
for radius_value in rad_array99:
    particles = np.where((r99 > radius_value) & (r99 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile99[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile99 = np.zeros(np.size(rad_array99))
h = 0
for radius_value in rad_array99:
    particles = np.where((r99 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile99[h] = how_many_particles * 500
    h += 1

# %%
전data98 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0098.txt")
dx98 = 전data98[:,4]
dy98 = 전data98[:,5]
dz98 = 전data98[:,6]
r98 = np.sqrt(dx98**2 + dy98**2 + dz98**2) # max: 1159.8037504669066, closest to 1160
rad_array98 = np.arange(10, 1160, dr, dtype=np.int64)

density_profile98 = np.zeros(np.size(rad_array98))
i = 0
for radius_value in rad_array98:
    particles = np.where((r98 > radius_value) & (r98 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile98[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile98 = np.zeros(np.size(rad_array98))
h = 0
for radius_value in rad_array98:
    particles = np.where((r98 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile98[h] = how_many_particles * 500
    h += 1

# %%
전data97 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0097.txt")
dx97 = 전data97[:,4]
dy97 = 전data97[:,5]
dz97 = 전data97[:,6]
r97 = np.sqrt(dx97**2 + dy97**2 + dz97**2) # max: 1133.0342604735702, closest to 1140
rad_array97 = np.arange(10, 1140, dr, dtype=np.int64)

density_profile97 = np.zeros(np.size(rad_array97))
i = 0
for radius_value in rad_array97:
    particles = np.where((r97 > radius_value) & (r97 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile97[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile97 = np.zeros(np.size(rad_array97))
h = 0
for radius_value in rad_array97:
    particles = np.where((r97 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile97[h] = how_many_particles * 500
    h += 1

# %%
전data96 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0096.txt")
dx96 = 전data96[:,4]
dy96 = 전data96[:,5]
dz96 = 전data96[:,6]
r96 = np.sqrt(dx96**2 + dy96**2 + dz96**2) # max: 1107.1245230144666, closest to 1110
rad_array96 = np.arange(10, 1110, dr, dtype=np.int64)

density_profile96 = np.zeros(np.size(rad_array96))
i = 0
for radius_value in rad_array96:
    particles = np.where((r96 > radius_value) & (r96 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile96[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile96 = np.zeros(np.size(rad_array96))
h = 0
for radius_value in rad_array96:
    particles = np.where((r96 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile96[h] = how_many_particles * 500
    h += 1

# %%
전data95 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0095.txt")
dx95 = 전data95[:,4]
dy95 = 전data95[:,5]
dz95 = 전data95[:,6]
r95 = np.sqrt(dx95**2 + dy95**2 + dz95**2) # max: 1077.3334101001926, closest to 1080
rad_array95 = np.arange(10, 1080, dr, dtype=np.int64)

density_profile95 = np.zeros(np.size(rad_array95))
i = 0
for radius_value in rad_array95:
    particles = np.where((r95 > radius_value) & (r95 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile95[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile95 = np.zeros(np.size(rad_array95))
h = 0
for radius_value in rad_array95:
    particles = np.where((r95 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile95[h] = how_many_particles * 500
    h += 1

# %%
전data94 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0094.txt")
dx94 = 전data94[:,4]
dy94 = 전data94[:,5]
dz94 = 전data94[:,6]
r94 = np.sqrt(dx94**2 + dy94**2 + dz94**2) # max: 1048.4359312895654, closest to 1050
rad_array94 = np.arange(10, 1050, dr, dtype=np.int64)

density_profile94 = np.zeros(np.size(rad_array94))
i = 0
for radius_value in rad_array94:
    particles = np.where((r94 > radius_value) & (r94 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile94[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile94 = np.zeros(np.size(rad_array94))
h = 0
for radius_value in rad_array94:
    particles = np.where((r94 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile94[h] = how_many_particles * 500
    h += 1

# %%
전data93 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0093.txt")
dx93 = 전data93[:,4]
dy93 = 전data93[:,5]
dz93 = 전data93[:,6]
r93 = np.sqrt(dx93**2 + dy93**2 + dz93**2) # max: 1011.1897602871333, closest to 1020
rad_array93 = np.arange(10, 1020, dr, dtype=np.int64)

density_profile93 = np.zeros(np.size(rad_array93))
i = 0
for radius_value in rad_array93:
    particles = np.where((r93 > radius_value) & (r93 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile93[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile93 = np.zeros(np.size(rad_array93))
h = 0
for radius_value in rad_array93:
    particles = np.where((r93 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile93[h] = how_many_particles * 500
    h += 1

# %%
전data92 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0092.txt")
dx92 = 전data92[:,4]
dy92 = 전data92[:,5]
dz92 = 전data92[:,6]
r92 = np.sqrt(dx92**2 + dy92**2 + dz92**2) # max: 961.4187275450432, closest to 970
rad_array92 = np.arange(10, 970, dr, dtype=np.int64)

density_profile92 = np.zeros(np.size(rad_array92))
i = 0
for radius_value in rad_array92:
    particles = np.where((r92 > radius_value) & (r92 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile92[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile92 = np.zeros(np.size(rad_array92))
h = 0
for radius_value in rad_array92:
    particles = np.where((r92 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile92[h] = how_many_particles * 500
    h += 1

# %%
전data91 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0091.txt")
dx91 = 전data91[:,4]
dy91 = 전data91[:,5]
dz91 = 전data91[:,6]
r91 = np.sqrt(dx91**2 + dy91**2 + dz91**2) # max: 917.4948515150644, closest to 920
rad_array91 = np.arange(10, 920, dr, dtype=np.int64)

density_profile91 = np.zeros(np.size(rad_array91))
i = 0
for radius_value in rad_array91:
    particles = np.where((r91 > radius_value) & (r91 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile91[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile91 = np.zeros(np.size(rad_array91))
h = 0
for radius_value in rad_array91:
    particles = np.where((r91 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile91[h] = how_many_particles * 500
    h += 1

# %%
전data71 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0071.txt")
dx71 = 전data71[:,4]
dy71 = 전data71[:,5]
dz71 = 전data71[:,6]
r71 = np.sqrt(dx71**2 + dy71**2 + dz71**2) # max: 550.9625505066837, closest to 560
rad_array71 = np.arange(10, 560, dr, dtype=np.int64)

density_profile71 = np.zeros(np.size(rad_array71))
i = 0
for radius_value in rad_array71:
    particles = np.where((r71 > radius_value) & (r71 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile71[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile71 = np.zeros(np.size(rad_array71))
h = 0
for radius_value in rad_array71:
    particles = np.where((r71 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile71[h] = how_many_particles * 500
    h += 1

# %%
전data51 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0051.txt")
dx51 = 전data51[:,4]
dy51 = 전data51[:,5]
dz51 = 전data51[:,6]
r51 = np.sqrt(dx51**2 + dy51**2 + dz51**2) # max: 394.7149024716827, closest to 400
rad_array51 = np.arange(10, 400, dr, dtype=np.int64)

density_profile51 = np.zeros(np.size(rad_array51))
i = 0
for radius_value in rad_array51:
    particles = np.where((r51 > radius_value) & (r51 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile51[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile51 = np.zeros(np.size(rad_array51))
h = 0
for radius_value in rad_array51:
    particles = np.where((r51 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile51[h] = how_many_particles * 500
    h += 1

# %%
'''THIS PART IS FOR DWARF 1 WITHOUT RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITHOUT RT'

# %%
전data290_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0290.txt")
dx290_noRT = 전data290_noRT[:,4]
dy290_noRT = 전data290_noRT[:,5]
dz290_noRT = 전data290_noRT[:,6]
r290_noRT = np.sqrt(dx290_noRT**2 + dy290_noRT**2 + dz290_noRT**2) # max: 11333.935323605565, closest to 11340
rad_array290_noRT = np.arange(10, 11280, dr, dtype=np.int64)

density_profile290_noRT = np.zeros(np.size(rad_array290_noRT))
i = 0
for radius_value in rad_array290_noRT:
    particles = np.where((r290_noRT > radius_value) & (r290_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile290_noRT[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile290_noRT = np.zeros(np.size(rad_array290_noRT))
h = 0
for radius_value in rad_array290_noRT:
    particles = np.where((r290_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile290_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data280_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0280.txt")
dx280_noRT = 전data280_noRT[:,4]
dy280_noRT = 전data280_noRT[:,5]
dz280_noRT = 전data280_noRT[:,6]
r280_noRT = np.sqrt(dx280_noRT**2 + dy280_noRT**2 + dz280_noRT**2) # max: 10866.528428099473, closest to 10870
rad_array280_noRT = np.arange(10, 10870, dr, dtype=np.int64)

density_profile280_noRT = np.zeros(np.size(rad_array280_noRT))
i = 0
for radius_value in rad_array280_noRT:
    particles = np.where((r280_noRT > radius_value) & (r280_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile280_noRT[i] = how_many_particles / shell_volume
    i += 1    
    
mass_profile280_noRT = np.zeros(np.size(rad_array280_noRT))
h = 0
for radius_value in rad_array280_noRT:
    particles = np.where((r280_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile280_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data270_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0270.txt")
dx270_noRT = 전data270_noRT[:,4]
dy270_noRT = 전data270_noRT[:,5]
dz270_noRT = 전data270_noRT[:,6]
r270_noRT = np.sqrt(dx270_noRT**2 + dy270_noRT**2 + dz270_noRT**2) # max: 10353.728025429693, closest to 10380
rad_array270_noRT = np.arange(10, 10380, dr, dtype=np.int64)

density_profile270_noRT = np.zeros(np.size(rad_array270_noRT))
i = 0
for radius_value in rad_array270_noRT:
    particles = np.where((r270_noRT > radius_value) & (r270_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile270_noRT[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile270_noRT = np.zeros(np.size(rad_array270_noRT))
h = 0
for radius_value in rad_array270_noRT:
    particles = np.where((r270_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile270_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data260_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0260.txt")
dx260_noRT = 전data260_noRT[:,4]
dy260_noRT = 전data260_noRT[:,5]
dz260_noRT = 전data260_noRT[:,6]
r260_noRT = np.sqrt(dx260_noRT**2 + dy260_noRT**2 + dz260_noRT**2) # max: 9737.857773282632, closest to 9740
rad_array260_noRT = np.arange(10, 9740, dr, dtype=np.int64)

density_profile260_noRT = np.zeros(np.size(rad_array260_noRT))
i = 0
for radius_value in rad_array260_noRT:
    particles = np.where((r260_noRT > radius_value) & (r260_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile260_noRT[i] = how_many_particles / shell_volume
    i += 1
    
mass_profile260_noRT = np.zeros(np.size(rad_array260_noRT))
h = 0
for radius_value in rad_array260_noRT:
    particles = np.where((r260_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile260_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data250_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0250.txt")
dx250_noRT = 전data250_noRT[:,4]
dy250_noRT = 전data250_noRT[:,5]
dz250_noRT = 전data250_noRT[:,6]
r250_noRT = np.sqrt(dx250_noRT**2 + dy250_noRT**2 + dz250_noRT**2) # max: 9045.751391493965, closest to 9060
rad_array250_noRT = np.arange(10, 9060, dr, dtype=np.int64)

density_profile250_noRT = np.zeros(np.size(rad_array250_noRT))
i = 0
for radius_value in rad_array250_noRT:
    particles = np.where((r250_noRT > radius_value) & (r250_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile250_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile250_noRT = np.zeros(np.size(rad_array250_noRT))
h = 0
for radius_value in rad_array250_noRT:
    particles = np.where((r250_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile250_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data240_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0240.txt")
dx240_noRT = 전data240_noRT[:,4]
dy240_noRT = 전data240_noRT[:,5]
dz240_noRT = 전data240_noRT[:,6]
r240_noRT = np.sqrt(dx240_noRT**2 + dy240_noRT**2 + dz240_noRT**2) # max: 8453.6627191447, closest to 8460
rad_array240_noRT = np.arange(10, 8460, dr, dtype=np.int64)

density_profile240_noRT = np.zeros(np.size(rad_array240_noRT))
i = 0
for radius_value in rad_array240_noRT:
    particles = np.where((r240_noRT > radius_value) & (r240_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile240_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile240_noRT = np.zeros(np.size(rad_array240_noRT))
h = 0
for radius_value in rad_array240_noRT:
    particles = np.where((r240_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile240_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data230_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0230.txt")
dx230_noRT = 전data230_noRT[:,4]
dy230_noRT = 전data230_noRT[:,5]
dz230_noRT = 전data230_noRT[:,6]
r230_noRT = np.sqrt(dx230_noRT**2 + dy230_noRT**2 + dz230_noRT**2) # max: 7746.81840150115, closest to 7800
rad_array230_noRT = np.arange(10, 7800, dr, dtype=np.int64)

density_profile230_noRT = np.zeros(np.size(rad_array230_noRT))
i = 0
for radius_value in rad_array230_noRT:
    particles = np.where((r230_noRT > radius_value) & (r230_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile230_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile230_noRT = np.zeros(np.size(rad_array230_noRT))
h = 0
for radius_value in rad_array230_noRT:
    particles = np.where((r230_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile230_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data220_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0220.txt")
dx220_noRT = 전data220_noRT[:,4]
dy220_noRT = 전data220_noRT[:,5]
dz220_noRT = 전data220_noRT[:,6]
r220_noRT = np.sqrt(dx220_noRT**2 + dy220_noRT**2 + dz220_noRT**2) # max: 7040.180741788807, closest to 7050
rad_array220_noRT = np.arange(10, 7050, dr, dtype=np.int64)

density_profile220_noRT = np.zeros(np.size(rad_array220_noRT))
i = 0
for radius_value in rad_array220_noRT:
    particles = np.where((r220_noRT > radius_value) & (r220_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile220_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile220_noRT = np.zeros(np.size(rad_array220_noRT))
h = 0
for radius_value in rad_array220_noRT:
    particles = np.where((r220_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile220_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data210_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0210.txt")
dx210_noRT = 전data210_noRT[:,4]
dy210_noRT = 전data210_noRT[:,5]
dz210_noRT = 전data210_noRT[:,6]
r210_noRT = np.sqrt(dx210_noRT**2 + dy210_noRT**2 + dz210_noRT**2) # max: 6435.552191577678, closest to 6480
rad_array210_noRT = np.arange(10, 6480, dr, dtype=np.int64)

density_profile210_noRT = np.zeros(np.size(rad_array210_noRT))
i = 0
for radius_value in rad_array210_noRT:
    particles = np.where((r210_noRT > radius_value) & (r210_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile210_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile210_noRT = np.zeros(np.size(rad_array210_noRT))
h = 0
for radius_value in rad_array210_noRT:
    particles = np.where((r210_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile210_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data200_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0200.txt")
dx200_noRT = 전data200_noRT[:,4]
dy200_noRT = 전data200_noRT[:,5]
dz200_noRT = 전data200_noRT[:,6]
r200_noRT = np.sqrt(dx200_noRT**2 + dy200_noRT**2 + dz200_noRT**2) # max: 5744.211231118595, closest to 5750
rad_array200_noRT = np.arange(10, 5750, dr, dtype=np.int64)

density_profile200_noRT = np.zeros(np.size(rad_array200_noRT))
i = 0
for radius_value in rad_array200_noRT:
    particles = np.where((r200_noRT > radius_value) & (r200_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile200_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile200_noRT = np.zeros(np.size(rad_array200_noRT))
h = 0
for radius_value in rad_array200_noRT:
    particles = np.where((r200_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile200_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data190_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0190.txt")
dx190_noRT = 전data190_noRT[:,4]
dy190_noRT = 전data190_noRT[:,5]
dz190_noRT = 전data190_noRT[:,6]
r190_noRT = np.sqrt(dx190_noRT**2 + dy190_noRT**2 + dz190_noRT**2) # max: 5101.190332034631, closest to 5160
rad_array190_noRT = np.arange(10, 5160, dr, dtype=np.int64)

density_profile190_noRT = np.zeros(np.size(rad_array190_noRT))
i = 0
for radius_value in rad_array190_noRT:
    particles = np.where((r190_noRT > radius_value) & (r190_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile190_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile190_noRT = np.zeros(np.size(rad_array190_noRT))
h = 0
for radius_value in rad_array190_noRT:
    particles = np.where((r190_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile190_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data180_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0180.txt")
dx180_noRT = 전data180_noRT[:,4]
dy180_noRT = 전data180_noRT[:,5]
dz180_noRT = 전data180_noRT[:,6]
r180_noRT = np.sqrt(dx180_noRT**2 + dy180_noRT**2 + dz180_noRT**2) # max: 4779.625005744802, closest to 4800
rad_array180_noRT = np.arange(10, 4800, dr, dtype=np.int64)

density_profile180_noRT = np.zeros(np.size(rad_array180_noRT))
i = 0
for radius_value in rad_array180_noRT:
    particles = np.where((r180_noRT > radius_value) & (r180_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile180_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile180_noRT = np.zeros(np.size(rad_array180_noRT))
h = 0
for radius_value in rad_array180_noRT:
    particles = np.where((r180_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile180_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data170_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0170.txt")
dx170_noRT = 전data170_noRT[:,4]
dy170_noRT = 전data170_noRT[:,5]
dz170_noRT = 전data170_noRT[:,6]
r170_noRT = np.sqrt(dx170_noRT**2 + dy170_noRT**2 + dz170_noRT**2) # max: 4540.972105566934, closest to 4560
rad_array170_noRT = np.arange(10, 4560, dr, dtype=np.int64)

density_profile170_noRT = np.zeros(np.size(rad_array170_noRT))
i = 0
for radius_value in rad_array170_noRT:
    particles = np.where((r170_noRT > radius_value) & (r170_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile170_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile170_noRT = np.zeros(np.size(rad_array170_noRT))
h = 0
for radius_value in rad_array170_noRT:
    particles = np.where((r170_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile170_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data160_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0160.txt")
dx160_noRT = 전data160_noRT[:,4]
dy160_noRT = 전data160_noRT[:,5]
dz160_noRT = 전data160_noRT[:,6]
r160_noRT = np.sqrt(dx160_noRT**2 + dy160_noRT**2 + dz160_noRT**2) # max: 3753.7547035842085, closest to 3760
rad_array160_noRT = np.arange(10, 3760, dr, dtype=np.int64)

density_profile160_noRT = np.zeros(np.size(rad_array160_noRT))
i = 0
for radius_value in rad_array160_noRT:
    particles = np.where((r160_noRT > radius_value) & (r160_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile160_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile160_noRT = np.zeros(np.size(rad_array160_noRT))
h = 0
for radius_value in rad_array160_noRT:
    particles = np.where((r160_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile160_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data150_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0150.txt")
dx150_noRT = 전data150_noRT[:,4]
dy150_noRT = 전data150_noRT[:,5]
dz150_noRT = 전data150_noRT[:,6]
r150_noRT = np.sqrt(dx150_noRT**2 + dy150_noRT**2 + dz150_noRT**2) # max: 2712.6740860997293, closest to 2760
rad_array150_noRT = np.arange(10, 2760, dr, dtype=np.int64)

density_profile150_noRT = np.zeros(np.size(rad_array150_noRT))
i = 0
for radius_value in rad_array150_noRT:
    particles = np.where((r150_noRT > radius_value) & (r150_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile150_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile150_noRT = np.zeros(np.size(rad_array150_noRT))
h = 0
for radius_value in rad_array150_noRT:
    particles = np.where((r150_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile150_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data140_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0140.txt")
dx140_noRT = 전data140_noRT[:,4]
dy140_noRT = 전data140_noRT[:,5]
dz140_noRT = 전data140_noRT[:,6]
r140_noRT = np.sqrt(dx140_noRT**2 + dy140_noRT**2 + dz140_noRT**2) # max: 2470.3048059146467, closest to 2480
rad_array140_noRT = np.arange(10, 2480, dr, dtype=np.int64)

density_profile140_noRT = np.zeros(np.size(rad_array140_noRT))
i = 0
for radius_value in rad_array140_noRT:
    particles = np.where((r140_noRT > radius_value) & (r140_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile140_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile140_noRT = np.zeros(np.size(rad_array140_noRT))
h = 0
for radius_value in rad_array140_noRT:
    particles = np.where((r140_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile140_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data130_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0130.txt")
dx130_noRT = 전data130_noRT[:,4]
dy130_noRT = 전data130_noRT[:,5]
dz130_noRT = 전data130_noRT[:,6]
r130_noRT = np.sqrt(dx130_noRT**2 + dy130_noRT**2 + dz130_noRT**2) # max: 2218.0197067752147, closest to 2220
rad_array130_noRT = np.arange(10, 2220, dr, dtype=np.int64)

density_profile130_noRT = np.zeros(np.size(rad_array130_noRT))
i = 0
for radius_value in rad_array130_noRT:
    particles = np.where((r130_noRT > radius_value) & (r130_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile130_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile130_noRT = np.zeros(np.size(rad_array130_noRT))
h = 0
for radius_value in rad_array130_noRT:
    particles = np.where((r130_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile130_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data120_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0120.txt")
dx120_noRT = 전data120_noRT[:,4]
dy120_noRT = 전data120_noRT[:,5]
dz120_noRT = 전data120_noRT[:,6]
r120_noRT = np.sqrt(dx120_noRT**2 + dy120_noRT**2 + dz120_noRT**2) # max: 1803.1395425349026, closest to 1810
rad_array120_noRT = np.arange(10, 1810, dr, dtype=np.int64)

density_profile120_noRT = np.zeros(np.size(rad_array120_noRT))
i = 0
for radius_value in rad_array120_noRT:
    particles = np.where((r120_noRT > radius_value) & (r120_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile120_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile120_noRT = np.zeros(np.size(rad_array120_noRT))
h = 0
for radius_value in rad_array120_noRT:
    particles = np.where((r120_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile120_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data110_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0110.txt")
dx110_noRT = 전data110_noRT[:,4]
dy110_noRT = 전data110_noRT[:,5]
dz110_noRT = 전data110_noRT[:,6]
r110_noRT = np.sqrt(dx110_noRT**2 + dy110_noRT**2 + dz110_noRT**2) # max: 1431.4151120109009, closest to 1440
rad_array110_noRT = np.arange(10, 1440, dr, dtype=np.int64)

density_profile110_noRT = np.zeros(np.size(rad_array110_noRT))
i = 0
for radius_value in rad_array110_noRT:
    particles = np.where((r110_noRT > radius_value) & (r110_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile110_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile110_noRT = np.zeros(np.size(rad_array110_noRT))
h = 0
for radius_value in rad_array110_noRT:
    particles = np.where((r110_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile110_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data100_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0100.txt")
dx100_noRT = 전data100_noRT[:,4]
dy100_noRT = 전data100_noRT[:,5]
dz100_noRT = 전data100_noRT[:,6]
r100_noRT = np.sqrt(dx100_noRT**2 + dy100_noRT**2 + dz100_noRT**2) # max: 1223.8940194176046, closest to 1230
rad_array100_noRT = np.arange(10, 1230, dr, dtype=np.int64)

density_profile100_noRT = np.zeros(np.size(rad_array100_noRT))
i = 0
for radius_value in rad_array100_noRT:
    particles = np.where((r100_noRT > radius_value) & (r100_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile100_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile100_noRT = np.zeros(np.size(rad_array100_noRT))
h = 0
for radius_value in rad_array100_noRT:
    particles = np.where((r100_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile100_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data99_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0099.txt")
dx99_noRT = 전data99_noRT[:,4]
dy99_noRT = 전data99_noRT[:,5]
dz99_noRT = 전data99_noRT[:,6]
r99_noRT = np.sqrt(dx99_noRT**2 + dy99_noRT**2 + dz99_noRT**2) # max: 1201.907921381236, closest to 1210
rad_array99_noRT = np.arange(10, 1210, dr, dtype=np.int64)

density_profile99_noRT = np.zeros(np.size(rad_array99_noRT))
i = 0
for radius_value in rad_array99_noRT:
    particles = np.where((r99_noRT > radius_value) & (r99_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile99_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile99_noRT = np.zeros(np.size(rad_array99_noRT))
h = 0
for radius_value in rad_array99_noRT:
    particles = np.where((r99_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile99_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data98_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0098.txt")
dx98_noRT = 전data98_noRT[:,4]
dy98_noRT = 전data98_noRT[:,5]
dz98_noRT = 전data98_noRT[:,6]
r98_noRT = np.sqrt(dx98_noRT**2 + dy98_noRT**2 + dz98_noRT**2) # max: 1182.4241729292287, closest to 1190
rad_array98_noRT = np.arange(10, 1190, dr, dtype=np.int64)

density_profile98_noRT = np.zeros(np.size(rad_array98_noRT))
i = 0
for radius_value in rad_array98_noRT:
    particles = np.where((r98_noRT > radius_value) & (r98_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile98_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile98_noRT = np.zeros(np.size(rad_array98_noRT))
h = 0
for radius_value in rad_array98_noRT:
    particles = np.where((r98_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile98_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data97_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0097.txt")
dx97_noRT = 전data97_noRT[:,4]
dy97_noRT = 전data97_noRT[:,5]
dz97_noRT = 전data97_noRT[:,6]
r97_noRT = np.sqrt(dx97_noRT**2 + dy97_noRT**2 + dz97_noRT**2) # max: 1157.5443549991564, closest to 1160
rad_array97_noRT = np.arange(10, 1160, dr, dtype=np.int64)

density_profile97_noRT = np.zeros(np.size(rad_array97_noRT))
i = 0
for radius_value in rad_array97_noRT:
    particles = np.where((r97_noRT > radius_value) & (r97_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile97_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile97_noRT = np.zeros(np.size(rad_array97_noRT))
h = 0
for radius_value in rad_array97_noRT:
    particles = np.where((r97_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile97_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data96_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0096.txt")
dx96_noRT = 전data96_noRT[:,4]
dy96_noRT = 전data96_noRT[:,5]
dz96_noRT = 전data96_noRT[:,6]
r96_noRT = np.sqrt(dx96_noRT**2 + dy96_noRT**2 + dz96_noRT**2) # max: 1125.281745822894, closest to 1130
rad_array96_noRT = np.arange(10, 1130, dr, dtype=np.int64)

density_profile96_noRT = np.zeros(np.size(rad_array96_noRT))
i = 0
for radius_value in rad_array96_noRT:
    particles = np.where((r96_noRT > radius_value) & (r96_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile96_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile96_noRT = np.zeros(np.size(rad_array96_noRT))
h = 0
for radius_value in rad_array96_noRT:
    particles = np.where((r96_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile96_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data95_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0095.txt")
dx95_noRT = 전data95_noRT[:,4]
dy95_noRT = 전data95_noRT[:,5]
dz95_noRT = 전data95_noRT[:,6]
r95_noRT = np.sqrt(dx95_noRT**2 + dy95_noRT**2 + dz95_noRT**2) # max: 1100.9314376245006, closest to 1110
rad_array95_noRT = np.arange(10, 1110, dr, dtype=np.int64)

density_profile95_noRT = np.zeros(np.size(rad_array95_noRT))
i = 0
for radius_value in rad_array95_noRT:
    particles = np.where((r95_noRT > radius_value) & (r95_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile95_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile95_noRT = np.zeros(np.size(rad_array95_noRT))
h = 0
for radius_value in rad_array95_noRT:
    particles = np.where((r95_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile95_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data94_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0094.txt")
dx94_noRT = 전data94_noRT[:,4]
dy94_noRT = 전data94_noRT[:,5]
dz94_noRT = 전data94_noRT[:,6]
r94_noRT = np.sqrt(dx94_noRT**2 + dy94_noRT**2 + dz94_noRT**2) # max: 1075.0069404492629, closest to 1080
rad_array94_noRT = np.arange(10, 1080, dr, dtype=np.int64)

density_profile94_noRT = np.zeros(np.size(rad_array94_noRT))
i = 0
for radius_value in rad_array94_noRT:
    particles = np.where((r94_noRT > radius_value) & (r94_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile94_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile94_noRT = np.zeros(np.size(rad_array94_noRT))
h = 0
for radius_value in rad_array94_noRT:
    particles = np.where((r94_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile94_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data93_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0093.txt")
dx93_noRT = 전data93_noRT[:,4]
dy93_noRT = 전data93_noRT[:,5]
dz93_noRT = 전data93_noRT[:,6]
r93_noRT = np.sqrt(dx93_noRT**2 + dy93_noRT**2 + dz93_noRT**2) # max: 1044.0576151275561, closest to 1050
rad_array93_noRT = np.arange(10, 1050, dr, dtype=np.int64)

density_profile93_noRT = np.zeros(np.size(rad_array93_noRT))
i = 0
for radius_value in rad_array93_noRT:
    particles = np.where((r93_noRT > radius_value) & (r93_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile93_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile93_noRT = np.zeros(np.size(rad_array93_noRT))
h = 0
for radius_value in rad_array93_noRT:
    particles = np.where((r93_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile93_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data92_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0092.txt")
dx92_noRT = 전data92_noRT[:,4]
dy92_noRT = 전data92_noRT[:,5]
dz92_noRT = 전data92_noRT[:,6]
r92_noRT = np.sqrt(dx92_noRT**2 + dy92_noRT**2 + dz92_noRT**2) # max: 1005.8614243767482, closest to 1010
rad_array92_noRT = np.arange(10, 1010, dr, dtype=np.int64)

density_profile92_noRT = np.zeros(np.size(rad_array92_noRT))
i = 0
for radius_value in rad_array92_noRT:
    particles = np.where((r92_noRT > radius_value) & (r92_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile92_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile92_noRT = np.zeros(np.size(rad_array92_noRT))
h = 0
for radius_value in rad_array92_noRT:
    particles = np.where((r92_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile92_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data91_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0091.txt")
dx91_noRT = 전data91_noRT[:,4]
dy91_noRT = 전data91_noRT[:,5]
dz91_noRT = 전data91_noRT[:,6]
r91_noRT = np.sqrt(dx91_noRT**2 + dy91_noRT**2 + dz91_noRT**2) # max: 968.6656127584315, closest to 970
rad_array91_noRT = np.arange(10, 970, dr, dtype=np.int64)

density_profile91_noRT = np.zeros(np.size(rad_array91_noRT))
i = 0
for radius_value in rad_array91_noRT:
    particles = np.where((r91_noRT > radius_value) & (r91_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile91_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile91_noRT = np.zeros(np.size(rad_array91_noRT))
h = 0
for radius_value in rad_array91_noRT:
    particles = np.where((r91_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile91_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data71_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0071.txt")
dx71_noRT = 전data71_noRT[:,4]
dy71_noRT = 전data71_noRT[:,5]
dz71_noRT = 전data71_noRT[:,6]
r71_noRT = np.sqrt(dx71_noRT**2 + dy71_noRT**2 + dz71_noRT**2) # max: 577.341871066827, closest to 580
rad_array71_noRT = np.arange(10, 580, dr, dtype=np.int64)

density_profile71_noRT = np.zeros(np.size(rad_array71_noRT))
i = 0
for radius_value in rad_array71_noRT:
    particles = np.where((r71_noRT > radius_value) & (r71_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile71_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile71_noRT = np.zeros(np.size(rad_array71_noRT))
h = 0
for radius_value in rad_array71_noRT:
    particles = np.where((r71_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile71_noRT[h] = how_many_particles * 500
    h += 1

# %%
전data51_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0051.txt")
dx51_noRT = 전data51_noRT[:,4]
dy51_noRT = 전data51_noRT[:,5]
dz51_noRT = 전data51_noRT[:,6]
r51_noRT = np.sqrt(dx51_noRT**2 + dy51_noRT**2 + dz51_noRT**2) # max: 394.7435926214388, closest to 400
rad_array51_noRT = np.arange(10, 400, dr, dtype=np.int64)

density_profile51_noRT = np.zeros(np.size(rad_array51_noRT))
i = 0
for radius_value in rad_array51_noRT:
    particles = np.where((r51_noRT > radius_value) & (r51_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile51_noRT[i] = how_many_particles / shell_volume
    i += 1
        
mass_profile51_noRT = np.zeros(np.size(rad_array51_noRT))
h = 0
for radius_value in rad_array51_noRT:
    particles = np.where((r51_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    mass_profile51_noRT[h] = how_many_particles * 500
    h += 1

# %%
# now, we calculate the difference between the density profiles at each redshift with and without RT.

# %%
# compare the size of the arrays with and without RT

arraylist = [density_profile290_noRT, density_profile290, density_profile280_noRT, density_profile280, \
             density_profile270_noRT, density_profile270, density_profile260_noRT, density_profile260, \
             density_profile250_noRT, density_profile250, density_profile240_noRT, density_profile240, \
             density_profile230_noRT, density_profile230, density_profile220_noRT, density_profile220, \
             density_profile210_noRT, density_profile210, density_profile200_noRT, density_profile200, \
             density_profile190_noRT, density_profile190, density_profile180_noRT, density_profile180, \
             density_profile170_noRT, density_profile170, density_profile160_noRT, density_profile160, \
             density_profile150_noRT, density_profile150, density_profile140_noRT, density_profile140, \
             density_profile130_noRT, density_profile130, density_profile120_noRT, density_profile120, \
             density_profile110_noRT, density_profile110, density_profile100_noRT, density_profile100, \
             density_profile99_noRT, density_profile99, density_profile98_noRT, density_profile98, \
             density_profile97_noRT, density_profile97, density_profile96_noRT, density_profile96, \
             density_profile95_noRT, density_profile95, density_profile94_noRT, density_profile94, \
             density_profile93_noRT, density_profile93, density_profile92_noRT, density_profile92, \
             density_profile91_noRT, density_profile91, density_profile71_noRT, density_profile71, \
             density_profile51_noRT, density_profile51]

i = 0
while i < len(arraylist):
    difference = np.size(arraylist[i]) - np.size(arraylist[i+1])
    if difference < 0:
        arraylist[i] = np.concatenate([arraylist[i], np.zeros(abs(difference))])
        print('RT expands further')
        i += 2
    elif difference > 0:
        arraylist[i+1] = np.concatenate([arraylist[i+1], np.zeros(abs(difference))])
        print('no_RT expands further')
        i += 2
    else:
        print('expands to the same size')
        i += 2

# diff = no_RT - RT for each redshift
        
j = 0
diff_list = []
while j < len(arraylist):
    diff = arraylist[j] - arraylist[j+1]
    diff_list.append(diff)
    j += 2
# Out:
# RT expands further
# RT expands further
# no_RT expands further
# expands to the same size
# RT expands further
# RT expands further
# RT expands further
# RT expands further
# no_RT expands further
# RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# RT expands further
# no_RT expands further
# expands to the same size
# RT expands further
# RT expands further
# RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# expands to the same size

# %%
# gather the redshifts

redshift = np.array([0.130, 0.245, 0.373, 0.514, 0.670, 0.841, 1.030, 1.238, 1.468, 1.721, 2.000, 2.308, \
                     2.648, 3.022, 3.435, 3.890, 4.392, 4.945, 5.555, 6.228, 6.299, 6.370, 6.443, 6.516, \
                     6.589, 6.664, 6.739, 6.815, 6.892, 8.595, 10.665])

# %%
# gathering the index at which rad_array = 100.
# it's discovered that the index is 9.

diff_array_100 = np.zeros(31)
i = 0
for diff in diff_list:
    diff_array_100[i] = diff[9]
    i += 1
    
plt.figure(figsize=(13, 13))

plt.plot(redshift, diff_array_100, color='#F5B700')

plt.xlabel('z', fontsize=16)
plt.ylabel('Δρ', fontsize=18) # using LATEX here!
plt.xticks(fontsize=10.5)
plt.yticks(fontsize=16)
plt.ylim(-0.003, 0.002)
plt.axhline(y=0, color='#000000', linestyle='--')
plt.text(4, 0.001, '''dwarf 1, difference measured\nat 100 pc from galactic center''', \
         fontsize=23, color='#F5B700', fontfamily='serif')

plt.title('redshift (z) vs. corresponding difference\nbetween density profiles, noRT − RT (Δρ)', \
          loc='center', fontsize=20)

plt.show()

# %%
# gathering the index at which rad_array = 50.
# it's discovered that the index is 4.

diff_array_50 = np.zeros(31)
i = 0
for diff in diff_list:
    diff_array_50[i] = diff[4]
    i += 1
    
plt.figure(figsize=(13, 13))

plt.plot(redshift, diff_array_50, color='#32CD32')

plt.xlabel('z', fontsize=16)
plt.ylabel('Δρ', fontsize=18) # using LATEX here!
plt.xticks(fontsize=10.5)
plt.yticks(fontsize=16)
plt.ylim(-0.003, 0.002)
plt.axhline(y=0, color='#000000', linestyle='--')
plt.text(5, -0.001, '''dwarf 1, difference measured\nat 50 pc from galactic center''', \
         fontsize=23, color='#32CD32', fontfamily='serif')

plt.title('redshift (z) vs. corresponding difference\nbetween density profiles, noRT − RT (Δρ)', \
          loc='center', fontsize=20)

plt.show()

# %%
# gathering the index at which rad_array = 10.
# it's discovered that the index is 0.

diff_array_10 = np.zeros(31)
i = 0
for diff in diff_list:
    diff_array_10[i] = diff[0]
    i += 1

plt.figure(figsize=(13, 13))

plt.plot(redshift, diff_array_10, color='#D81159')

plt.xlabel('z', fontsize=16)
plt.ylabel('Δρ', fontsize=18) # using LATEX here!
plt.xticks(fontsize=10.5)
plt.yticks(fontsize=16)
plt.ylim(-0.003, 0.002)
plt.axhline(y=0, color='#000000', linestyle='--')
plt.text(5.4, -0.0025, '''dwarf 1, difference measured\nat 10 pc from galactic center''', \
         fontsize=23, color='#D81159', fontfamily='serif')

plt.title('redshift (z) vs. corresponding difference\nbetween density profiles, noRT − RT (Δρ)', \
          loc='center', fontsize=20)

plt.show()

# %%
# combine all the lines into ONE plot!

plt.figure(figsize=(13, 13))

plt.plot(redshift, diff_array_10, color='#D81159')
plt.plot(redshift, diff_array_50, color='#32CD32')
plt.plot(redshift, diff_array_100, color='#F5B700')

line1 = mpatches.Patch(color='#D81159', label='10 pc from galactic center')
line2 = mpatches.Patch(color='#32CD32', label='50 pc from galactic center')
line3 = mpatches.Patch(color='#F5B700', label='100 pc from galactic center')

plt.legend(handles=[line1, line2, line3], loc='upper right')

plt.xlabel('z', fontsize=16)
plt.ylabel('Δρ', fontsize=18) # using LATEX here!
plt.xticks(fontsize=10.5)
plt.yticks(fontsize=16)
plt.ylim(-0.003, 0.002)
plt.axhline(y=0, color='#000000', linestyle='--')

plt.title('redshift (z) vs. corresponding difference between\ndensity profiles of dwarf 1, noRT − RT (Δρ)', \
          loc='center', fontsize=20)

plt.show()

# %% [markdown]
# REMEMBER: 500 solar masses is the mass per particle

# %%
# compare the size of the arrays with and without RT

massarray = [mass_profile290_noRT, mass_profile290, mass_profile280_noRT, mass_profile280, \
             mass_profile270_noRT, mass_profile270, mass_profile260_noRT, mass_profile260, \
             mass_profile250_noRT, mass_profile250, mass_profile240_noRT, mass_profile240, \
             mass_profile230_noRT, mass_profile230, mass_profile220_noRT, mass_profile220, \
             mass_profile210_noRT, mass_profile210, mass_profile200_noRT, mass_profile200, \
             mass_profile190_noRT, mass_profile190, mass_profile180_noRT, mass_profile180, \
             mass_profile170_noRT, mass_profile170, mass_profile160_noRT, mass_profile160, \
             mass_profile150_noRT, mass_profile150, mass_profile140_noRT, mass_profile140, \
             mass_profile130_noRT, mass_profile130, mass_profile120_noRT, mass_profile120, \
             mass_profile110_noRT, mass_profile110, mass_profile100_noRT, mass_profile100, \
             mass_profile99_noRT, mass_profile99, mass_profile98_noRT, mass_profile98, \
             mass_profile97_noRT, mass_profile97, mass_profile96_noRT, mass_profile96, \
             mass_profile95_noRT, mass_profile95, mass_profile94_noRT, mass_profile94, \
             mass_profile93_noRT, mass_profile93, mass_profile92_noRT, mass_profile92, \
             mass_profile91_noRT, mass_profile91, mass_profile71_noRT, mass_profile71, \
             mass_profile51_noRT, mass_profile51]

i = 0
while i < len(massarray):
    difference = np.size(massarray[i]) - np.size(massarray[i+1])
    if difference < 0:
        massarray[i] = np.concatenate([massarray[i], np.zeros(abs(difference))])
        print('RT expands further')
        i += 2
    elif difference > 0:
        massarray[i+1] = np.concatenate([massarray[i+1], np.zeros(abs(difference))])
        print('no_RT expands further')
        i += 2
    else:
        print('expands to the same size')
        i += 2

# diff = no_RT - RT for each redshift
        
j = 0
list_diff = []
while j < len(massarray):
    diff = massarray[j] - massarray[j+1]
    list_diff.append(diff)
    j += 2
# Out:
# RT expands further
# RT expands further
# no_RT expands further
# expands to the same size
# RT expands further
# RT expands further
# RT expands further
# RT expands further
# no_RT expands further
# RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# RT expands further
# no_RT expands further
# expands to the same size
# RT expands further
# RT expands further
# RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# no_RT expands further
# expands to the same size
