# %%
# all the density stuff for high z measurements of dwarf 1, normalized.

# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

from IPython.display import Latex

# %matplotlib inline

from NFW import NFW

# %%
dr = 10

# %%
'''THIS PART IS FOR DWARF 1 WITH RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITH RT'

# %%
전data290 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0290.txt")
dx290 = 전data290[:,4]
dy290 = 전data290[:,5]
dz290 = 전data290[:,6]
r290 = np.sqrt(dx290**2 + dy290**2 + dz290**2) # max: 11415.825965662318, closest to 11420
rad_array290 = np.arange(10, 11420, dr, dtype=np.int64)
density_profile290 = np.zeros(np.size(rad_array290))
i = 0
for radius_value in rad_array290:
    particles = np.where((r290 > radius_value) & (r290 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile290[i] = how_many_particles / shell_volume
    i += 1
densityprof290 = density_profile290 / density_profile290[0]

# %%
전data270 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0270.txt")
dx270 = 전data270[:,4]
dy270 = 전data270[:,5]
dz270 = 전data270[:,6]
r270 = np.sqrt(dx270**2 + dy270**2 + dz270**2) # max: 10304.377486889249, closest to 10310
rad_array270 = np.arange(10, 10310, dr, dtype=np.int64)
density_profile270 = np.zeros(np.size(rad_array270))
i = 0
for radius_value in rad_array270:
    particles = np.where((r270 > radius_value) & (r270 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile270[i] = how_many_particles / shell_volume
    i += 1
densityprof270 = density_profile270 / density_profile270[0]

# %%
전data250 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0250.txt")
dx250 = 전data250[:,4]
dy250 = 전data250[:,5]
dz250 = 전data250[:,6]
r250 = np.sqrt(dx250**2 + dy250**2 + dz250**2) # max: 9092.83786101821, closest to 9100
rad_array250 = np.arange(10, 9100, dr, dtype=np.int64)
density_profile250 = np.zeros(np.size(rad_array250))
i = 0
for radius_value in rad_array250:
    particles = np.where((r250 > radius_value) & (r250 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile250[i] = how_many_particles / shell_volume
    i += 1
densityprof250 = density_profile250 / density_profile250[0]

# %%
전data230 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0230.txt")
dx230 = 전data230[:,4]
dy230 = 전data230[:,5]
dz230 = 전data230[:,6]
r230 = np.sqrt(dx230**2 + dy230**2 + dz230**2) # max: 7816.878257007077, closest to 7820
rad_array230 = np.arange(10, 7820, dr, dtype=np.int64)
density_profile230 = np.zeros(np.size(rad_array230))
i = 0
for radius_value in rad_array230:
    particles = np.where((r230 > radius_value) & (r230 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile230[i] = how_many_particles / shell_volume
    i += 1
densityprof230 = density_profile230 / density_profile230[0]

# %%
전data210 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0210.txt")
dx210 = 전data210[:,4]
dy210 = 전data210[:,5]
dz210 = 전data210[:,6]
r210 = np.sqrt(dx210**2 + dy210**2 + dz210**2) # max: 6403.483270570543, closest to 6410
rad_array210 = np.arange(10, 7070, dr, dtype=np.int64)
density_profile210 = np.zeros(np.size(rad_array210))
i = 0
for radius_value in rad_array210:
    particles = np.where((r210 > radius_value) & (r210 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile210[i] = how_many_particles / shell_volume
    i += 1
densityprof210 = density_profile210 / density_profile210[0]

# %%
전data190 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0190.txt")
dx190 = 전data190[:,4]
dy190 = 전data190[:,5]
dz190 = 전data190[:,6]
r190 = np.sqrt(dx190**2 + dy190**2 + dz190**2) # max: 5113.111121256088, closest to 5120
rad_array190 = np.arange(10, 5760, dr, dtype=np.int64)
density_profile190 = np.zeros(np.size(rad_array190))
i = 0
for radius_value in rad_array190:
    particles = np.where((r190 > radius_value) & (r190 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile190[i] = how_many_particles / shell_volume
    i += 1
densityprof190 = density_profile190 / density_profile190[0]

# %%
전data180 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 RT/dwarf_dm_5e8_rt_0180.txt")
dx180 = 전data180[:,4]
dy180 = 전data180[:,5]
dz180 = 전data180[:,6]
r180 = np.sqrt(dx180**2 + dy180**2 + dz180**2) # max: 4762.8993529580275, closest to 4770
rad_array180 = np.arange(10, 4770, dr, dtype=np.int64)
density_profile180 = np.zeros(np.size(rad_array180))
i = 0
for radius_value in rad_array180:
    particles = np.where((r180 > radius_value) & (r180 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile180[i] = how_many_particles / shell_volume
    i += 1
densityprof180 = density_profile180 / density_profile180[0]

# %%
'''THIS PART IS FOR DWARF 1 WITHOUT RT'''
# Out:
# 'THIS PART IS FOR DWARF 1 WITHOUT RT'

# %%
전data290_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0290.txt")
dx290_noRT = 전data290_noRT[:,4]
dy290_noRT = 전data290_noRT[:,5]
dz290_noRT = 전data290_noRT[:,6]
r290_noRT = np.sqrt(dx290_noRT**2 + dy290_noRT**2 + dz290_noRT**2) # max: 11333.935323605565, closest to 11280
rad_array290_noRT = np.arange(10, 11280, dr, dtype=np.int64)
density_profile290_noRT = np.zeros(np.size(rad_array290_noRT))
i = 0
for radius_value in rad_array290_noRT:
    particles = np.where((r290_noRT > radius_value) & (r290_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile290_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof290_noRT = density_profile290_noRT / density_profile290_noRT[0]

# %%
전data270_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0270.txt")
dx270_noRT = 전data270_noRT[:,4]
dy270_noRT = 전data270_noRT[:,5]
dz270_noRT = 전data270_noRT[:,6]
r270_noRT = np.sqrt(dx270_noRT**2 + dy270_noRT**2 + dz270_noRT**2) # max: 10353.728025429693, closest to 10380
rad_array270_noRT = np.arange(10, 10380, dr, dtype=np.int64)
density_profile270_noRT = np.zeros(np.size(rad_array270_noRT))
i = 0
for radius_value in rad_array270_noRT:
    particles = np.where((r270_noRT > radius_value) & (r270_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile270_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof270_noRT = density_profile270_noRT / density_profile270_noRT[0]

# %%
전data250_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0250.txt")
dx250_noRT = 전data250_noRT[:,4]
dy250_noRT = 전data250_noRT[:,5]
dz250_noRT = 전data250_noRT[:,6]
r250_noRT = np.sqrt(dx250_noRT**2 + dy250_noRT**2 + dz250_noRT**2) # max: 9045.751391493965, closest to 9060
rad_array250_noRT = np.arange(10, 9060, dr, dtype=np.int64)
density_profile250_noRT = np.zeros(np.size(rad_array250_noRT))
i = 0
for radius_value in rad_array250_noRT:
    particles = np.where((r250_noRT > radius_value) & (r250_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile250_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof250_noRT = density_profile250_noRT / density_profile250_noRT[0]

# %%
전data230_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0230.txt")
dx230_noRT = 전data230_noRT[:,4]
dy230_noRT = 전data230_noRT[:,5]
dz230_noRT = 전data230_noRT[:,6]
r230_noRT = np.sqrt(dx230_noRT**2 + dy230_noRT**2 + dz230_noRT**2) # max: 7746.81840150115, closest to 7800
rad_array230_noRT = np.arange(10, 7800, dr, dtype=np.int64)
density_profile230_noRT = np.zeros(np.size(rad_array230_noRT))
i = 0
for radius_value in rad_array230_noRT:
    particles = np.where((r230_noRT > radius_value) & (r230_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile230_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof230_noRT = density_profile230_noRT / density_profile230_noRT[0]

# %%
전data210_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0210.txt")
dx210_noRT = 전data210_noRT[:,4]
dy210_noRT = 전data210_noRT[:,5]
dz210_noRT = 전data210_noRT[:,6]
r210_noRT = np.sqrt(dx210_noRT**2 + dy210_noRT**2 + dz210_noRT**2) # max: 6435.552191577678, closest to 6480
rad_array210_noRT = np.arange(10, 6480, dr, dtype=np.int64)
density_profile210_noRT = np.zeros(np.size(rad_array210_noRT))
i = 0
for radius_value in rad_array210_noRT:
    particles = np.where((r210_noRT > radius_value) & (r210_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile210_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof210_noRT = density_profile210_noRT / density_profile210_noRT[0]

# %%
전data190_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0190.txt")
dx190_noRT = 전data190_noRT[:,4]
dy190_noRT = 전data190_noRT[:,5]
dz190_noRT = 전data190_noRT[:,6]
r190_noRT = np.sqrt(dx190_noRT**2 + dy190_noRT**2 + dz190_noRT**2) # max: 5101.290332034631, closest to 5160
rad_array190_noRT = np.arange(10, 5160, dr, dtype=np.int64)
density_profile190_noRT = np.zeros(np.size(rad_array190_noRT))
i = 0
for radius_value in rad_array190_noRT:
    particles = np.where((r190_noRT > radius_value) & (r190_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile190_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof190_noRT = density_profile190_noRT / density_profile190_noRT[0]

# %%
전data180_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 1 no RT/dwarf_dm_5e8_0180.txt")
dx180_noRT = 전data180_noRT[:,4]
dy180_noRT = 전data180_noRT[:,5]
dz180_noRT = 전data180_noRT[:,6]
r180_noRT = np.sqrt(dx180_noRT**2 + dy180_noRT**2 + dz180_noRT**2) # max: 4779.625005744802, closest to 4800
rad_array180_noRT = np.arange(10, 4800, dr, dtype=np.int64)
density_profile180_noRT = np.zeros(np.size(rad_array180_noRT))
i = 0
for radius_value in rad_array180_noRT:
    particles = np.where((r180_noRT > radius_value) & (r180_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile180_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof180_noRT = density_profile180_noRT / density_profile180_noRT[0]

# %%
plt.figure(figsize=(13,13))

# dwarf1_noRT.txt

plt.plot(rad_array290_noRT, densityprof290_noRT, color=(0.5, 0.1, 0.9, 1), linewidth=2)
plt.plot(rad_array270_noRT, densityprof270_noRT, color=(0.5, 0.1, 0.9, 0.86), linewidth=2)
plt.plot(rad_array250_noRT, densityprof250_noRT, color=(0.5, 0.1, 0.9, 0.79), linewidth=2)
plt.plot(rad_array230_noRT, densityprof230_noRT, color=(0.5, 0.1, 0.9, 0.70), linewidth=2)
plt.plot(rad_array210_noRT, densityprof210_noRT, color=(0.5, 0.1, 0.9, 0.62), linewidth=2)
plt.plot(rad_array190_noRT, densityprof190_noRT, color=(0.5, 0.1, 0.9, 0.56), linewidth=2)
plt.plot(rad_array180_noRT, densityprof180_noRT, color=(0.5, 0.1, 0.9, 0.48), linewidth=2)

purple12 = mpatches.Patch(color=(0.5, 0.1, 0.9, 1), label='z = 0.130')
purple11 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.86), label='z = 0.373')
purple10 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.79), label='z = 0.670')
purple9 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.70), label='z = 1.030')
purple8 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.62), label='z = 1.468')
purple7 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.56), label='z = 2.000')
purple6 = mpatches.Patch(color=(0.5, 0.1, 0.9, 0.48), label='z = 2.308')

# dwarf1_RT.txt

plt.plot(rad_array290, densityprof290, color=(0.2, 0.9, 0.6, 1), linewidth=2)
plt.plot(rad_array270, densityprof270, color=(0.2, 0.9, 0.6, 0.86), linewidth=2)
plt.plot(rad_array250, densityprof250, color=(0.2, 0.9, 0.6, 0.79), linewidth=2)
plt.plot(rad_array230, densityprof230, color=(0.2, 0.9, 0.6, 0.70), linewidth=2)
plt.plot(rad_array210, densityprof210, color=(0.2, 0.9, 0.6, 0.62), linewidth=2)
plt.plot(rad_array190, densityprof190, color=(0.2, 0.9, 0.6, 0.56), linewidth=2)
plt.plot(rad_array180, densityprof180, color=(0.2, 0.9, 0.6, 0.48), linewidth=2)

green11 = mpatches.Patch(color=(0.2, 0.9, 0.6, 1), label='z = 0.130')
green10 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.86), label='z = 0.373')
green9 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.79), label='z = 0.670')
green8 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.70), label='z = 1.030')
green7 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.62), label='z = 1.468')
green6 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.56), label='z = 2.000')
green5 = mpatches.Patch(color=(0.2, 0.9, 0.6, 0.48), label='z = 2.308')

first_legend = plt.legend(handles=[green11, green10, green9, \
                                   green8, green7, green6, green5],loc='upper right')
plt.gca().add_artist(first_legend)
second_legend = plt.legend(handles=[purple12, purple11, purple10, \
                                    purple9, purple8, purple7, purple6],loc='lower left')

plt.xlabel('distance from center of galaxy halo (pc)', fontsize=17)
plt.ylabel('normalized dark matter density', fontsize=17) # using LATEX here!
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(10,10**4.2)
plt.xscale('log')
plt.yscale('log')

plt.title('normalized dark matter density profiles of dwarf 1, high z,\nwith RT (green) and without RT (purple), bin size = ' \
          + str(dr), loc='center', fontsize=20)

plt.show()

# %%
# now, we calculate the difference between the density profiles at each redshift with and without RT.

# %%
# compare the size of the arrays with and without RT

arraylist = [densityprof290_noRT, densityprof290, \
             densityprof270_noRT, densityprof270, \
             densityprof250_noRT, densityprof250, \
             densityprof230_noRT, densityprof230, \
             densityprof210_noRT, densityprof210, \
             densityprof190_noRT, densityprof190, \
             densityprof180_noRT, densityprof180]
i = 0
while i < len(arraylist):
    difference = np.size(arraylist[i]) - np.size(arraylist[i+1])
    if difference < 0:
        arraylist[i] = np.concatenate([arraylist[i], np.zeros(abs(difference))])
        print('with RT longer')
        i += 2
    else:
        arraylist[i+1] = np.concatenate([arraylist[i+1], np.zeros(abs(difference))])
        print('without RT longer')
        i += 2
        
diff290 = arraylist[0] - arraylist[1]
diff270 = arraylist[2] - arraylist[3]
diff250 = arraylist[4] - arraylist[5]
diff230 = arraylist[6] - arraylist[7]
diff210 = arraylist[8] - arraylist[9]
diff190 = arraylist[10] - arraylist[11]
diff180 = arraylist[12] - arraylist[13]
# Out:
# with RT longer
# without RT longer
# with RT longer
# with RT longer
# with RT longer
# with RT longer
# without RT longer

# %%
print(diff230)
# Out:
# [ 0.00000000e+00  2.29344820e-02 -1.12916454e-01 -2.25448922e-02
#  -4.64312868e-02  2.27468532e-03  4.07234387e-03  2.66253489e-03
#  -7.61426029e-04 -9.30337575e-03 -1.19637528e-02 -3.67505286e-03
#  -4.86630577e-03 -1.13685797e-02 -3.78113842e-03 -3.42449835e-03
#  -1.18329251e-02 -4.14725761e-03 -9.17958216e-03 -6.39917538e-03
#   4.58567123e-04 -8.38235024e-04 -1.04092552e-02 -5.21982325e-03
#   4.13476809e-03 -2.20120551e-03 -4.83809227e-03 -4.48115824e-03
#  -1.07712784e-03 -8.08911848e-04 -2.29998685e-03  5.23593642e-04
#   5.95185093e-04 -4.38886029e-03 -2.92776524e-04 -3.58917532e-03
#  -1.33981489e-03 -1.84213047e-03 -1.28459270e-03 -3.52917875e-03
#  -2.20749055e-03 -2.56020751e-03 -3.03846217e-03 -2.06822495e-03
#  -2.62186067e-03 -2.59095508e-03 -1.99778040e-03 -1.25009463e-03
#  -1.69100165e-03 -1.67530469e-03 -2.58762532e-03 -1.49461105e-03
#  -1.74472649e-03 -9.38105599e-04 -1.52812253e-03 -1.22470243e-03
#  -1.70328857e-03 -1.46254532e-03 -8.73695642e-04 -8.36541172e-04
#  -1.11303576e-03 -1.67108902e-03 -8.55692252e-04 -1.09427992e-03
#  -6.46273770e-04 -1.02789425e-03 -1.47265370e-03 -6.34019396e-04
#  -9.22644153e-04 -1.27623890e-03 -5.24712245e-05 -8.95284346e-04
#  -9.98707880e-04 -1.88875306e-04 -6.88278141e-04 -8.21116040e-04
#  -6.18049809e-04 -8.25178339e-04 -8.63892571e-04 -3.88596668e-04
#  -6.98848700e-04 -1.24667563e-03 -1.04853471e-03 -4.01918787e-04
#  -8.67333986e-04 -6.17202463e-04 -6.90846023e-04 -6.47375200e-04
#  -2.46333450e-06 -2.58067626e-06 -2.27479315e-06  1.03891741e-07
#  -2.11631326e-06 -2.30295707e-06 -2.82780279e-06 -3.10836186e-06
#  -4.84564782e-06 -2.08970673e-06  5.15696937e-07 -7.49600731e-08
#  -6.56665226e-07 -2.65694234e-06 -2.47764253e-08  4.63852616e-07
#  -7.10520032e-07 -6.66527838e-07 -1.87544886e-06 -2.37619288e-06
#  -1.55849591e-06 -9.43625581e-07  2.08443417e-06 -1.96875711e-06
#   1.43633605e-06 -8.25468812e-07 -2.03285051e-07  9.36539854e-07
#  -2.95023698e-06 -9.91183475e-07  1.49224655e-06  1.92118061e-07
#  -6.67529848e-07 -3.13138435e-06  5.14170337e-07 -2.94916672e-06
#   8.91137830e-07 -1.61843256e-06 -3.24751550e-06 -1.86475282e-08
#  -1.85523602e-06 -1.00597099e-06 -2.39937075e-06 -7.14990743e-07
#   2.24442086e-07  1.76868664e-07 -1.50556363e-06 -2.76215784e-06
#  -6.15888133e-07  2.94776717e-07 -1.44532299e-06 -1.57651060e-06
#  -6.80636608e-07 -2.92217567e-06 -1.65994934e-06 -5.05879428e-07
#  -1.08390064e-06 -4.46697543e-06 -9.88853695e-07 -1.48890598e-06
#  -2.62797294e-06 -1.93326034e-06 -1.04369631e-06 -2.63246468e-06
#  -1.66268890e-06  1.26932230e-06 -1.64357826e-06  1.54444114e-06
#  -2.88127537e-06 -1.95716088e-06  3.92198666e-07  1.44003067e-06
#   6.08817642e-07  5.12506441e-07  2.18882371e-07 -3.32220079e-07
#   7.75656713e-07 -3.34620972e-06 -1.33933988e-05 -1.51083071e-05
#  -1.53338450e-05 -1.29211961e-05 -1.43083821e-05 -1.43766803e-05
#  -1.01007404e-05]

# %%
plt.figure(figsize=(10,10))

plt.plot(rad_array290, diff290, color='#241e4e', linewidth=2)
plt.plot(rad_array270_noRT, diff270, color='#960200', linewidth=2)
plt.plot(rad_array250, np.abs(diff250), color='#da627d', linewidth=2)
plt.plot(rad_array230, np.abs(diff230), color='#ffa5ab', linewidth=2)
plt.plot(rad_array210, diff210, color='#ce6c47', linewidth=2)
plt.plot(rad_array190, diff190, color='#ffd046', linewidth=2)
plt.plot(rad_array180_noRT, diff180, color='#eadaa2', linewidth=2)

green11 = mpatches.Patch(color='#241e4e', label='z = 0.130')
green10 = mpatches.Patch(color='#960200', label='z = 0.373') #
green9 = mpatches.Patch(color='#da627d', label='z = 0.670')
green8 = mpatches.Patch(color='#ffa5ab', label='z = 1.030')
green7 = mpatches.Patch(color='#ce6c47', label='z = 1.468')
green6 = mpatches.Patch(color='#ffd046', label='z = 2.000')
green5 = mpatches.Patch(color='#eadaa2', label='z = 2.308') #

first_legend = plt.legend(handles=[green11, green10, green9, green8, green7, green6, green5],loc='upper right')

plt.xlabel('distance from center of galaxy halo (pc)', fontsize=16)
plt.ylabel('normalized dark matter density difference', fontsize=16) # using LATEX here!
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlim(10,1000)
plt.xscale('log')
plt.yscale('log')

plt.title('difference between the normalized density profiles\nwith and without RT, dwarf 1, high z, bin size = 10', \
          loc='center', fontsize=18)

plt.show()
