# %%
# all the density stuff for low z measurements of dwarf 2, normalized.

# %%
# import modules
import numpy as np

# import plotting modules
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib inline

from IPython.display import Latex

# %matplotlib inline

from NFW import NFW

# %%
dr = 10

# %%
'''THIS PART IS FOR DWARF 2 WITH RT'''
# Out:
# 'THIS PART IS FOR DWARF 2 WITH RT'

# %%
전data160 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 RT/dwarf_dm_7e8_rt_0160.txt")
dx160 = 전data160[:,4]
dy160 = 전data160[:,5]
dz160 = 전data160[:,6]
r160 = np.sqrt(dx160**2 + dy160**2 + dz160**2) # max: 3008.0379161438045, closest to 3010
rad_array160 = np.arange(10, 3010, dr, dtype=np.int64)
density_profile160 = np.zeros(np.size(rad_array160))
i = 0
for radius_value in rad_array160:
    particles = np.where((r160 > radius_value) & (r160 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile160[i] = how_many_particles / shell_volume
    i += 1
densityprof160 = density_profile160 / density_profile160[0]

# %%
전data140 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 RT/dwarf_dm_7e8_rt_0140.txt")
dx140 = 전data140[:,4]
dy140 = 전data140[:,5]
dz140 = 전data140[:,6]
r140 = np.sqrt(dx140**2 + dy140**2 + dz140**2) # max: 1993.4467109677573, closest to 2000
rad_array140 = np.arange(10, 2000, dr, dtype=np.int64)
density_profile140 = np.zeros(np.size(rad_array140))
i = 0
for radius_value in rad_array140:
    particles = np.where((r140 > radius_value) & (r140 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile140[i] = how_many_particles / shell_volume
    i += 1
densityprof140 = density_profile140 / density_profile140[0]

# %%
전data120 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 RT/dwarf_dm_7e8_rt_0120.txt")
dx120 = 전data120[:,4]
dy120 = 전data120[:,5]
dz120 = 전data120[:,6]
r120 = np.sqrt(dx120**2 + dy120**2 + dz120**2) # max: 1122.366751066308, closest to 1130
rad_array120 = np.arange(10, 1130, dr, dtype=np.int64)
density_profile120 = np.zeros(np.size(rad_array120))
i = 0
for radius_value in rad_array120:
    particles = np.where((r120 > radius_value) & (r120 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile120[i] = how_many_particles / shell_volume
    i += 1
densityprof120 = density_profile120 / density_profile120[0]

# %%
전data90 = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 RT/dwarf_dm_7e8_rt_0090.txt")
dx90 = 전data90[:,4]
dy90 = 전data90[:,5]
dz90 = 전data90[:,6]
r90 = np.sqrt(dx90**2 + dy90**2 + dz90**2) # max: 742.2491179209106, closest to 750
rad_array90 = np.arange(10, 750, dr, dtype=np.int64)
density_profile90 = np.zeros(np.size(rad_array90))
i = 0
for radius_value in rad_array90:
    particles = np.where((r90 > radius_value) & (r90 < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile90[i] = how_many_particles / shell_volume
    i += 1
densityprof90 = density_profile90 / density_profile90[0]

# %%
'''THIS PART IS FOR DWARF 2 WITHOUT RT'''
# Out:
# 'THIS PART IS FOR DWARF 2 WITHOUT RT'

# %%
전data160_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 no RT/dwarf_dm_7e8_0160.txt")
dx160_noRT = 전data160_noRT[:,4]
dy160_noRT = 전data160_noRT[:,5]
dz160_noRT = 전data160_noRT[:,6]
r160_noRT = np.sqrt(dx160_noRT**2 + dy160_noRT**2 + dz160_noRT**2) # max: 2965.885138782433, closest to 2970
rad_array160_noRT = np.arange(10, 2970, dr, dtype=np.int64)
density_profile160_noRT = np.zeros(np.size(rad_array160_noRT))
i = 0
for radius_value in rad_array160_noRT:
    particles = np.where((r160_noRT > radius_value) & (r160_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile160_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof160_noRT = density_profile160_noRT / density_profile160_noRT[0]

# %%
전data140_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 no RT/dwarf_dm_7e8_0140.txt")
dx140_noRT = 전data140_noRT[:,4]
dy140_noRT = 전data140_noRT[:,5]
dz140_noRT = 전data140_noRT[:,6]
r140_noRT = np.sqrt(dx140_noRT**2 + dy140_noRT**2 + dz140_noRT**2) # max: 2009.7003304320672, closest to 2010
rad_array140_noRT = np.arange(10, 2010, dr, dtype=np.int64)
density_profile140_noRT = np.zeros(np.size(rad_array140_noRT))
i = 0
for radius_value in rad_array140_noRT:
    particles = np.where((r140_noRT > radius_value) & (r140_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile140_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof140_noRT = density_profile140_noRT / density_profile140_noRT[0]

# %%
전data120_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 no RT/dwarf_dm_7e8_0120.txt")
dx120_noRT = 전data120_noRT[:,4]
dy120_noRT = 전data120_noRT[:,5]
dz120_noRT = 전data120_noRT[:,6]
r120_noRT = np.sqrt(dx120_noRT**2 + dy120_noRT**2 + dz120_noRT**2) # max: 1145.2150980048318, closest to 1150
rad_array120_noRT = np.arange(10, 1150, dr, dtype=np.int64)
density_profile120_noRT = np.zeros(np.size(rad_array120_noRT))
i = 0
for radius_value in rad_array120_noRT:
    particles = np.where((r120_noRT > radius_value) & (r120_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile120_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof120_noRT = density_profile120_noRT / density_profile120_noRT[0]

# %%
전data90_noRT = np.loadtxt("D:/Research/ultra-faint dwarf galaxies/dwarf 2 no RT/dwarf_dm_7e8_0090.txt")
dx90_noRT = 전data90_noRT[:,4]
dy90_noRT = 전data90_noRT[:,5]
dz90_noRT = 전data90_noRT[:,6]
r90_noRT = np.sqrt(dx90_noRT**2 + dy90_noRT**2 + dz90_noRT**2) # max: 714.7123920374195, closest to 720
rad_array90_noRT = np.arange(10, 720, dr, dtype=np.int64)
density_profile90_noRT = np.zeros(np.size(rad_array90_noRT))
i = 0
for radius_value in rad_array90_noRT:
    particles = np.where((r90_noRT > radius_value) & (r90_noRT < (radius_value + dr)))
    how_many_particles = np.size(particles)
    shell_volume = 4/3*np.pi*((radius_value + dr)**3 - radius_value**3)
    density_profile90_noRT[i] = how_many_particles / shell_volume
    i += 1
densityprof90_noRT = density_profile90_noRT / density_profile90_noRT[0]

# %%
plt.figure(figsize=(13,13))

# dwarf2_noRT.txt

plt.plot(rad_array160_noRT, densityprof160_noRT, color=(0.9, 0.3, 0.4, 0.42), linewidth=2)
plt.plot(rad_array140_noRT, densityprof140_noRT, color=(0.9, 0.3, 0.4, 0.38), linewidth=2)
plt.plot(rad_array120_noRT, densityprof120_noRT, color=(0.9, 0.3, 0.4, 0.36), linewidth=2)
plt.plot(rad_array90_noRT, densityprof90_noRT, color=(0.9, 0.3, 0.4, 0.28), linewidth=2)

red4 = mpatches.Patch(color=(0.9, 0.3, 0.4, 0.42), label='z = 3.022')
red3 = mpatches.Patch(color=(0.9, 0.3, 0.4, 0.38), label='z = 3.890')
red2 = mpatches.Patch(color=(0.9, 0.3, 0.4, 0.36), label='z = 4.945')
red1 = mpatches.Patch(color=(0.9, 0.3, 0.4, 0.28), label='z = 6.228')

# dwarf2_RT.txt

plt.plot(rad_array160, densityprof160, color=(0.1, 0.36, 0.9, 0.42), linewidth=2)
plt.plot(rad_array140, densityprof140, color=(0.1, 0.36, 0.9, 0.38), linewidth=2)
plt.plot(rad_array120, densityprof120, color=(0.1, 0.36, 0.9, 0.36), linewidth=2)
plt.plot(rad_array90, densityprof90, color=(0.1, 0.36, 0.9, 0.28), linewidth=2)

blue4 = mpatches.Patch(color=(0.1, 0.36, 0.9, 0.42), label='z = 3.022')
blue3 = mpatches.Patch(color=(0.1, 0.36, 0.9, 0.38), label='z = 3.890')
blue2 = mpatches.Patch(color=(0.1, 0.36, 0.9, 0.36), label='z = 4.945')
blue1 = mpatches.Patch(color=(0.1, 0.36, 0.9, 0.28), label='z = 6.228')

first_legend = plt.legend(handles=[blue4, blue3, blue2, blue1],loc='upper right')
plt.gca().add_artist(first_legend)
second_legend = plt.legend(handles=[red4, red3, red2, red1],loc='lower left')

plt.xlabel('distance from center of galaxy halo (pc)', fontsize=17)
plt.ylabel('normalized dark matter density', fontsize=17) # using LATEX here!
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(10,10**4.2)
plt.xscale('log')
plt.yscale('log')

plt.title('normalized dark matter density profiles of dwarf 2, low z,\nwith RT (blue) and without RT (red), bin size = ' \
          + str(dr), loc='center', fontsize=20)

plt.show()
